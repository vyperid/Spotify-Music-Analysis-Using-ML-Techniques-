# %%
import pandas as pd 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials 
from collections import Counter

# %%
sp = spotipy.Spotify() 

cid ="userid" 

secret = "secretid"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 

sp.trace=False

# %%
playlist_l = sp.user_playlist("playlistname", "playlistid") 

playlist_d = sp.user_playlist("playlistname", "playlistid") 

playlist_l
playlist_d
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/4HC1kIY2bof1CHfZqmo8u1'},
#  'followers': {'href': None, 'total': 1},
#  'href': 'https://api.spotify.com/v1/playlists/4HC1kIY2bof1CHfZqmo8u1?additional_types=track',
#  'id': '4HC1kIY2bof1CHfZqmo8u1',
#  'images': [],
#  'name': 'Disliked',
#  'owner': {'display_name': 'demirbilekf',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#   'href': 'https://api.spotify.com/v1/users/bullseye012',
#   'id': 'bullseye012',
#   'type': 'user',
#   'uri': 'spotify:user:bullseye012'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'NDYsNjc3ZmVjN2E0ZjFhMjk2ZGU5ODZiNTYwNjBjY2RiZGRmZmViYTRkYQ==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/4HC1kIY2bof1CHfZqmo8u1/tracks?offset=0&limit=100&additional_types=track',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:4HC1kIY2bof1CHfZqmo8u1'}

# %%
liked_songs = playlist_l["tracks"]["items"] 
liked_songs
# Out:
# [{'added_at': '2022-12-05T18:12:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#       'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#       'id': '19eLuQmk9aCobbVDHc6eek',
#       'name': 'Louis Armstrong',
#       'type': 'artist',
#       'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6mmv0gwumlFGWDGJXF4yEv'},
#     'href': 'https://api.spotify.com/v1/albums/6mmv0gwumlFGWDGJXF4yEv',
#     'id': '6mmv0gwumlFGWDGJXF4yEv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273845a5660b804e5f3e821fbed',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02845a5660b804e5f3e821fbed',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851845a5660b804e5f3e821fbed',
#       'width': 64}],
#     'name': 'What A Wonderful World',
#     'release_date': '1968-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6mmv0gwumlFGWDGJXF4yEv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#      'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#      'id': '19eLuQmk9aCobbVDHc6eek',
#      'name': 'Louis Armstrong',
#      'type': 'artist',
#      'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 139226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC16758823'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/29U7stRjqHU6rMiS8BfaI9'},
#    'href': 'https://api.spotify.com/v1/tracks/29U7stRjqHU6rMiS8BfaI9',
#    'id': '29U7stRjqHU6rMiS8BfaI9',
#    'is_local': False,
#    'name': 'What A Wonderful World',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:29U7stRjqHU6rMiS8BfaI9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:12:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/75nZGvjStgCUavXcsYsXf7'},
#     'href': 'https://api.spotify.com/v1/albums/75nZGvjStgCUavXcsYsXf7',
#     'id': '75nZGvjStgCUavXcsYsXf7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c5eb6ea693bf928ca3e13661',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c5eb6ea693bf928ca3e13661',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c5eb6ea693bf928ca3e13661',
#       'width': 64}],
#     'name': 'The Shark in Your Water',
#     'release_date': '2022-05-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:75nZGvjStgCUavXcsYsXf7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 188864,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAN112100630'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2MfwT3SKUyF0na2LCa2fCp'},
#    'href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#    'id': '2MfwT3SKUyF0na2LCa2fCp',
#    'is_local': False,
#    'name': 'Cornflower Blue',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0ed6d70223d702345bc06dd471fea0674c867298?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:12:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#       'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#       'id': '53A0W3U0s8diEn9RhXQhVz',
#       'name': 'Keane',
#       'type': 'artist',
#       'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5QqVXRTiGpLgmo1YNoz9Bk'},
#     'href': 'https://api.spotify.com/v1/albums/5QqVXRTiGpLgmo1YNoz9Bk',
#     'id': '5QqVXRTiGpLgmo1YNoz9Bk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1a0d9a7cf88083aac260c33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1a0d9a7cf88083aac260c33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1a0d9a7cf88083aac260c33',
#       'width': 64}],
#     'name': 'Hopes and Fears (Deluxe Edition)',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:5QqVXRTiGpLgmo1YNoz9Bk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#      'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#      'id': '53A0W3U0s8diEn9RhXQhVz',
#      'name': 'Keane',
#      'type': 'artist',
#      'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 345933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAN0400091'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5b7wNSn8yuj5ZZ3JAlzoBt'},
#    'href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#    'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#    'is_local': False,
#    'name': 'She Has No Time',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#       'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#       'id': '50JJSqHUf2RQ9xsHs0KMHg',
#       'name': 'Jon Bellion',
#       'type': 'artist',
#       'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2e8nzTZ0HtK94IifOWgN7o'},
#     'href': 'https://api.spotify.com/v1/albums/2e8nzTZ0HtK94IifOWgN7o',
#     'id': '2e8nzTZ0HtK94IifOWgN7o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a01c1fddc334c0bd15e4452d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a01c1fddc334c0bd15e4452d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a01c1fddc334c0bd15e4452d',
#       'width': 64}],
#     'name': 'The Human Condition',
#     'release_date': '2016-06-10',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2e8nzTZ0HtK94IifOWgN7o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#      'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#      'id': '50JJSqHUf2RQ9xsHs0KMHg',
#      'name': 'Jon Bellion',
#      'type': 'artist',
#      'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 217603,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71603666'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1CnPYaKxTVb4LWOtiGOm0m'},
#    'href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#    'id': '1CnPYaKxTVb4LWOtiGOm0m',
#    'is_local': False,
#    'name': 'All Time Low',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7x2x5b3TNBaiQqlKUwlNVM'},
#     'href': 'https://api.spotify.com/v1/albums/7x2x5b3TNBaiQqlKUwlNVM',
#     'id': '7x2x5b3TNBaiQqlKUwlNVM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736293eae65ffd59901275b003',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026293eae65ffd59901275b003',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516293eae65ffd59901275b003',
#       'width': 64}],
#     'name': 'Baby Teeth',
#     'release_date': '2018-03-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7x2x5b3TNBaiQqlKUwlNVM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 281843,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMAAK1807702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1M8OAc4NnD5GFMUiqjebaS'},
#    'href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#    'id': '1M8OAc4NnD5GFMUiqjebaS',
#    'is_local': False,
#    'name': 'Baby Teeth',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8865a35ec0a2572bbbd005d7049ed327c64d4fa6?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#       'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#       'id': '3kZdsaTYgaaolNxpnJ4iDe',
#       'name': 'Son Lux',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6dJKjotJRGEE9rmGgmxDWu'},
#     'href': 'https://api.spotify.com/v1/albums/6dJKjotJRGEE9rmGgmxDWu',
#     'id': '6dJKjotJRGEE9rmGgmxDWu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27363e74fdfbcd4f37a18ab1596',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0263e74fdfbcd4f37a18ab1596',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485163e74fdfbcd4f37a18ab1596',
#       'width': 64}],
#     'name': 'Everything Everywhere All at Once (Original Motion Picture Soundtrack)',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 49,
#     'type': 'album',
#     'uri': 'spotify:album:6dJKjotJRGEE9rmGgmxDWu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#      'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#      'id': '3kZdsaTYgaaolNxpnJ4iDe',
#      'name': 'Son Lux',
#      'type': 'artist',
#      'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/20vuBdFblWUo2FCOvUzusB'},
#      'href': 'https://api.spotify.com/v1/artists/20vuBdFblWUo2FCOvUzusB',
#      'id': '20vuBdFblWUo2FCOvUzusB',
#      'name': 'David Byrne',
#      'type': 'artist',
#      'uri': 'spotify:artist:20vuBdFblWUo2FCOvUzusB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 161022,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMB622200545'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/20UK2eUwlRzNuW60gzITuj'},
#    'href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#    'id': '20UK2eUwlRzNuW60gzITuj',
#    'is_local': False,
#    'name': 'This Is A Life',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1e99529b9b43ffb0121222ad16451e8db8cdf551?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 45,
#    'type': 'track',
#    'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#       'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#       'id': '3ICflSq6ZgYAIrm2CTkfVP',
#       'name': 'The Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1v4O55JGou3T0Vlj06fdXz'},
#     'href': 'https://api.spotify.com/v1/albums/1v4O55JGou3T0Vlj06fdXz',
#     'id': '1v4O55JGou3T0Vlj06fdXz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273015c484a7aca592df1a77828',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02015c484a7aca592df1a77828',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851015c484a7aca592df1a77828',
#       'width': 64}],
#     'name': 'The Singles Plus',
#     'release_date': '1987-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:1v4O55JGou3T0Vlj06fdXz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#      'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#      'id': '3ICflSq6ZgYAIrm2CTkfVP',
#      'name': 'The Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 269906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE6400209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4mn2kNTqiGLwaUR8JdhJ1l'},
#    'href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#    'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#    'is_local': False,
#    'name': 'House of the Rising Sun',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3f5ed575e67b66ef0c40ac1c52b3c11e022d8499?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#     'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#     'id': '6400dnyeDyD2mIFHfkwHXN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512f85b65d3ac4d3d7f806ca11',
#       'width': 64}],
#     'name': 'Pablo Honey',
#     'release_date': '1993-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6400dnyeDyD2mIFHfkwHXN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 238640,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAYE9200070'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6b2oQwSGFkzsMtQruIWm2p'},
#    'href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#    'id': '6b2oQwSGFkzsMtQruIWm2p',
#    'is_local': False,
#    'name': 'Creep',
#    'popularity': 2,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#       'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#       'id': '1kDGbuxWknIKx4FlgWxiSp',
#       'name': 'Nothing But Thieves',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0vBxqUHwetFn5jCwAKX7Uk'},
#     'href': 'https://api.spotify.com/v1/albums/0vBxqUHwetFn5jCwAKX7Uk',
#     'id': '0vBxqUHwetFn5jCwAKX7Uk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273176e29e598499208ff338ae1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02176e29e598499208ff338ae1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851176e29e598499208ff338ae1',
#       'width': 64}],
#     'name': 'Nothing But Thieves (Track by Track)',
#     'release_date': '2015-10-09',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:0vBxqUHwetFn5jCwAKX7Uk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#      'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#      'id': '1kDGbuxWknIKx4FlgWxiSp',
#      'name': 'Nothing But Thieves',
#      'type': 'artist',
#      'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
# ...
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731551c93dfa33ea4f30ef4eea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511551c93dfa33ea4f30ef4eea',
#       'width': 64}],
#     'name': 'Smoke + Mirrors (Deluxe)',
#     'release_date': '2015-10-30',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:6ecx4OFG0nlUMqAi9OXQER'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#      'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#      'id': '53XhwfbYqKCa1cC15pYq2q',
#      'name': 'Imagine Dragons',
#      'type': 'artist',
#      'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LC',
#     'LI',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 217973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71417943'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6FQcdl2PzmsoXRF3F1flZ5'},
#    'href': 'https://api.spotify.com/v1/tracks/6FQcdl2PzmsoXRF3F1flZ5',
#    'id': '6FQcdl2PzmsoXRF3F1flZ5',
#    'is_local': False,
#    'name': 'Second Chances',
#    'popularity': 44,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:6FQcdl2PzmsoXRF3F1flZ5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:05:20Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5T7a0lQ6x5ABq8LtJGyTm2'},
#       'href': 'https://api.spotify.com/v1/artists/5T7a0lQ6x5ABq8LtJGyTm2',
#       'id': '5T7a0lQ6x5ABq8LtJGyTm2',
#       'name': 'Rope Sect',
#       'type': 'artist',
#       'uri': 'spotify:artist:5T7a0lQ6x5ABq8LtJGyTm2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/06MHIEC2w0OA7QrqHDW67W'},
#     'href': 'https://api.spotify.com/v1/albums/06MHIEC2w0OA7QrqHDW67W',
#     'id': '06MHIEC2w0OA7QrqHDW67W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273310226321de080f13774bbf3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02310226321de080f13774bbf3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851310226321de080f13774bbf3',
#       'width': 64}],
#     'name': 'Handsome Youth',
#     'release_date': '2019-03-18',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:06MHIEC2w0OA7QrqHDW67W'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5T7a0lQ6x5ABq8LtJGyTm2'},
#      'href': 'https://api.spotify.com/v1/artists/5T7a0lQ6x5ABq8LtJGyTm2',
#      'id': '5T7a0lQ6x5ABq8LtJGyTm2',
#      'name': 'Rope Sect',
#      'type': 'artist',
#      'uri': 'spotify:artist:5T7a0lQ6x5ABq8LtJGyTm2'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 226890,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DELJ81914286'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5kkqN6Lx3ZioloqqxC7Kyj'},
#    'href': 'https://api.spotify.com/v1/tracks/5kkqN6Lx3ZioloqqxC7Kyj',
#    'id': '5kkqN6Lx3ZioloqqxC7Kyj',
#    'is_local': False,
#    'name': 'Handsome Youth',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7c2999846962dddd8540c3ff72d8fefc6ed42aed?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5kkqN6Lx3ZioloqqxC7Kyj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:05:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vkqYmiPBYLaalcmjujWxK'},
#     'href': 'https://api.spotify.com/v1/albums/5vkqYmiPBYLaalcmjujWxK',
#     'id': '5vkqYmiPBYLaalcmjujWxK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de3c04b5fc750b68899b20a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de3c04b5fc750b68899b20a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de3c04b5fc750b68899b20a9',
#       'width': 64}],
#     'name': 'In Rainbows',
#     'release_date': '2007-12-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5vkqYmiPBYLaalcmjujWxK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 228746,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBSTK0700005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Qv2Nby1xTr9pQyjkrc94J'},
#    'href': 'https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9pQyjkrc94J',
#    'id': '5Qv2Nby1xTr9pQyjkrc94J',
#    'is_local': False,
#    'name': 'All I Need',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f3ea52a5c549e46e86495e2329cf79d2c03c0a27?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5Qv2Nby1xTr9pQyjkrc94J'},
#   'video_thumbnail': {'url': None}}]

# %%
liked_ids = [] 
for i in range(len(liked_songs)): 
    liked_ids.append(liked_songs[i]["track"]["id"])

# %%
liked_features = sp.audio_features(liked_ids) 

liked_features
# Out:
# [{'danceability': 0.271,
#   'energy': 0.165,
#   'key': 5,
#   'loudness': -20.652,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.729,
#   'instrumentalness': 1.6e-06,
#   'liveness': 0.118,
#   'valence': 0.203,
#   'tempo': 77.082,
#   'type': 'audio_features',
#   'id': '29U7stRjqHU6rMiS8BfaI9',
#   'uri': 'spotify:track:29U7stRjqHU6rMiS8BfaI9',
#   'track_href': 'https://api.spotify.com/v1/tracks/29U7stRjqHU6rMiS8BfaI9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/29U7stRjqHU6rMiS8BfaI9',
#   'duration_ms': 139227,
#   'time_signature': 4},
#  {'danceability': 0.177,
#   'energy': 0.215,
#   'key': 3,
#   'loudness': -9.886,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.807,
#   'instrumentalness': 0.000125,
#   'liveness': 0.0921,
#   'valence': 0.0415,
#   'tempo': 75.862,
#   'type': 'audio_features',
#   'id': '2MfwT3SKUyF0na2LCa2fCp',
#   'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MfwT3SKUyF0na2LCa2fCp',
#   'duration_ms': 188864,
#   'time_signature': 3},
#  {'danceability': 0.53,
#   'energy': 0.497,
#   'key': 0,
#   'loudness': -11.348,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.498,
#   'instrumentalness': 0.000384,
#   'liveness': 0.0665,
#   'valence': 0.1,
#   'tempo': 141.977,
#   'type': 'audio_features',
#   'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#   'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5b7wNSn8yuj5ZZ3JAlzoBt',
#   'duration_ms': 345933,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -4.188,
#   'mode': 1,
#   'speechiness': 0.0828,
#   'acousticness': 0.0584,
#   'instrumentalness': 0,
#   'liveness': 0.0933,
#   'valence': 0.505,
#   'tempo': 90.246,
#   'type': 'audio_features',
#   'id': '1CnPYaKxTVb4LWOtiGOm0m',
#   'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CnPYaKxTVb4LWOtiGOm0m',
#   'duration_ms': 217603,
#   'time_signature': 4},
#  {'danceability': 0.214,
#   'energy': 0.367,
#   'key': 6,
#   'loudness': -10.858,
#   'mode': 0,
#   'speechiness': 0.0321,
#   'acousticness': 0.844,
#   'instrumentalness': 0.0181,
#   'liveness': 0.188,
#   'valence': 0.175,
#   'tempo': 79.854,
#   'type': 'audio_features',
#   'id': '1M8OAc4NnD5GFMUiqjebaS',
#   'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M8OAc4NnD5GFMUiqjebaS',
#   'duration_ms': 281844,
#   'time_signature': 4},
#  {'danceability': 0.236,
#   'energy': 0.156,
#   'key': 1,
#   'loudness': -16.973,
#   'mode': 0,
#   'speechiness': 0.0389,
#   'acousticness': 0.731,
#   'instrumentalness': 0,
#   'liveness': 0.127,
#   'valence': 0.0919,
#   'tempo': 85.78,
#   'type': 'audio_features',
#   'id': '20UK2eUwlRzNuW60gzITuj',
#   'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj',
#   'track_href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20UK2eUwlRzNuW60gzITuj',
#   'duration_ms': 161022,
#   'time_signature': 4},
#  {'danceability': 0.316,
#   'energy': 0.484,
#   'key': 9,
#   'loudness': -9.11,
#   'mode': 0,
#   'speechiness': 0.0308,
#   'acousticness': 0.000334,
#   'instrumentalness': 0.00445,
#   'liveness': 0.0912,
#   'valence': 0.299,
#   'tempo': 117.363,
#   'type': 'audio_features',
#   'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#   'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mn2kNTqiGLwaUR8JdhJ1l',
#   'duration_ms': 269907,
#   'time_signature': 3},
#  {'danceability': 0.515,
#   'energy': 0.43,
#   'key': 7,
#   'loudness': -9.935,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.0102,
#   'instrumentalness': 0.000141,
#   'liveness': 0.129,
#   'valence': 0.104,
#   'tempo': 91.841,
#   'type': 'audio_features',
#   'id': '6b2oQwSGFkzsMtQruIWm2p',
#   'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p',
#   'track_href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2oQwSGFkzsMtQruIWm2p',
#   'duration_ms': 238640,
#   'time_signature': 4},
#  {'danceability': 0.443,
#   'energy': 0.461,
#   'key': 0,
#   'loudness': -6.224,
#   'mode': 0,
#   'speechiness': 0.0257,
#   'acousticness': 0.143,
#   'instrumentalness': 0.00956,
#   'liveness': 0.0952,
#   'valence': 0.182,
#   'tempo': 71.989,
#   'type': 'audio_features',
#   'id': '2yoxjQT7P2D1dhvxJGWWi8',
#   'uri': 'spotify:track:2yoxjQT7P2D1dhvxJGWWi8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2yoxjQT7P2D1dhvxJGWWi8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2yoxjQT7P2D1dhvxJGWWi8',
#   'duration_ms': 227013,
#   'time_signature': 4},
#  {'danceability': 0.444,
#   'energy': 0.819,
#   'key': 10,
#   'loudness': -4.078,
#   'mode': 0,
#   'speechiness': 0.341,
#   'acousticness': 0.106,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.747,
#   'tempo': 82.695,
#   'type': 'audio_features',
#   'id': '3QGsuHI8jO1Rx4JWLUh9jd',
#   'uri': 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QGsuHI8jO1Rx4JWLUh9jd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QGsuHI8jO1Rx4JWLUh9jd',
#   'duration_ms': 187973,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.762,
#   'key': 5,
#   'loudness': -5.148,
#   'mode': 0,
#   'speechiness': 0.0654,
#   'acousticness': 0.0242,
#   'instrumentalness': 4.52e-06,
#   'liveness': 0.211,
#   'valence': 0.64,
#   'tempo': 179.853,
#   'type': 'audio_features',
#   'id': '1Qv1K2UaXTyCjppspCtNoS',
#   'uri': 'spotify:track:1Qv1K2UaXTyCjppspCtNoS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Qv1K2UaXTyCjppspCtNoS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Qv1K2UaXTyCjppspCtNoS',
#   'duration_ms': 191960,
#   'time_signature': 4},
#  {'danceability': 0.535,
#   'energy': 0.0609,
#   'key': 11,
#   'loudness': -17.805,
#   'mode': 1,
#   'speechiness': 0.0542,
#   'acousticness': 0.93,
#   'instrumentalness': 0.000144,
#   'liveness': 0.106,
#   'valence': 0.172,
#   'tempo': 106.261,
#   'type': 'audio_features',
#   'id': '7lY3juj1MLv4gjpRxkj27Z',
#   'uri': 'spotify:track:7lY3juj1MLv4gjpRxkj27Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lY3juj1MLv4gjpRxkj27Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lY3juj1MLv4gjpRxkj27Z',
#   'duration_ms': 224813,
#   'time_signature': 3},
#  {'danceability': 0.653,
#   'energy': 0.505,
#   'key': 10,
#   'loudness': -7.102,
#   'mode': 0,
#   'speechiness': 0.0261,
#   'acousticness': 0.766,
#   'instrumentalness': 8.11e-06,
#   'liveness': 0.0701,
#   'valence': 0.388,
#   'tempo': 96.109,
#   'type': 'audio_features',
#   'id': '7Dq7IjABZfw3LZDZRwPBEu',
#   'uri': 'spotify:track:7Dq7IjABZfw3LZDZRwPBEu',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Dq7IjABZfw3LZDZRwPBEu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Dq7IjABZfw3LZDZRwPBEu',
#   'duration_ms': 228907,
#   'time_signature': 4},
#  {'danceability': 0.567,
#   'energy': 0.391,
#   'key': 1,
#   'loudness': -9.106,
#   'mode': 1,
#   'speechiness': 0.0268,
#   'acousticness': 0.74,
#   'instrumentalness': 0.277,
#   'liveness': 0.0645,
#   'valence': 0.269,
#   'tempo': 123.909,
#   'type': 'audio_features',
#   'id': '4gAIUEY7VkeiKQOPwIYaYb',
#   'uri': 'spotify:track:4gAIUEY7VkeiKQOPwIYaYb',
#   'track_href': 'https://api.spotify.com/v1/tracks/4gAIUEY7VkeiKQOPwIYaYb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4gAIUEY7VkeiKQOPwIYaYb',
#   'duration_ms': 297591,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.574,
#   'key': 7,
#   'loudness': -11.302,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'acousticness': 0.0401,
#   'instrumentalness': 2.6e-06,
#   'liveness': 0.154,
#   'valence': 0.234,
#   'tempo': 125.407,
#   'type': 'audio_features',
#   'id': '4Yv6i6vsR5RoSsuTX8Anr3',
#   'uri': 'spotify:track:4Yv6i6vsR5RoSsuTX8Anr3',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Yv6i6vsR5RoSsuTX8Anr3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Yv6i6vsR5RoSsuTX8Anr3',
#   'duration_ms': 250794,
#   'time_signature': 4},
#  {'danceability': 0.393,
#   'energy': 0.487,
#   'key': 0,
#   'loudness': -6.348,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.3,
#   'tempo': 151.958,
#   'type': 'audio_features',
#   'id': '77KnJc8o5G1eKVwX5ywMeZ',
#   'uri': 'spotify:track:77KnJc8o5G1eKVwX5ywMeZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/77KnJc8o5G1eKVwX5ywMeZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77KnJc8o5G1eKVwX5ywMeZ',
#   'duration_ms': 230867,
#   'time_signature': 4},
#  {'danceability': 0.44,
#   'energy': 0.317,
#   'key': 8,
#   'loudness': -9.258,
#   'mode': 1,
#   'speechiness': 0.0531,
#   'acousticness': 0.891,
#   'instrumentalness': 4.78e-06,
#   'liveness': 0.141,
#   'valence': 0.268,
#   'tempo': 169.914,
#   'type': 'audio_features',
#   'id': '6xGruZOHLs39ZbVccQTuPZ',
#   'uri': 'spotify:track:6xGruZOHLs39ZbVccQTuPZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xGruZOHLs39ZbVccQTuPZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xGruZOHLs39ZbVccQTuPZ',
#   'duration_ms': 233456,
#   'time_signature': 3},
#  {'danceability': 0.682,
#   'energy': 0.683,
#   'key': 8,
#   'loudness': -6.444,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.156,
#   'instrumentalness': 2.32e-05,
#   'liveness': 0.273,
#   'valence': 0.64,
#   'tempo': 120.023,
#   'type': 'audio_features',
#   'id': '57RA3JGafJm5zRtKJiKPIm',
#   'uri': 'spotify:track:57RA3JGafJm5zRtKJiKPIm',
#   'track_href': 'https://api.spotify.com/v1/tracks/57RA3JGafJm5zRtKJiKPIm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57RA3JGafJm5zRtKJiKPIm',
#   'duration_ms': 178000,
#   'time_signature': 4},
#  {'danceability': 0.274,
#   'energy': 0.293,
#   'key': 2,
#   'loudness': -13.257,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'acousticness': 0.877,
#   'instrumentalness': 0.399,
#   'liveness': 0.195,
#   'valence': 0.0429,
#   'tempo': 122.554,
#   'type': 'audio_features',
#   'id': '44CAg3EYpDo9lwHCkuHHaF',
#   'uri': 'spotify:track:44CAg3EYpDo9lwHCkuHHaF',
#   'track_href': 'https://api.spotify.com/v1/tracks/44CAg3EYpDo9lwHCkuHHaF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44CAg3EYpDo9lwHCkuHHaF',
#   'duration_ms': 180032,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.0809,
#   'key': 0,
#   'loudness': -17.282,
#   'mode': 1,
#   'speechiness': 0.0365,
#   'acousticness': 0.983,
#   'instrumentalness': 0.41,
#   'liveness': 0.114,
#   'valence': 0.0922,
#   'tempo': 114.355,
#   'type': 'audio_features',
#   'id': '2LXtyj95dK56ENS1QLt4IB',
#   'uri': 'spotify:track:2LXtyj95dK56ENS1QLt4IB',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LXtyj95dK56ENS1QLt4IB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LXtyj95dK56ENS1QLt4IB',
#   'duration_ms': 160093,
#   'time_signature': 3},
#  {'danceability': 0.77,
#   'energy': 0.0731,
#   'key': 11,
#   'loudness': -20.432,
#   'mode': 1,
#   'speechiness': 0.0404,
#   'acousticness': 0.921,
#   'instrumentalness': 0.00447,
#   'liveness': 0.105,
#   'valence': 0.18,
#   'tempo': 112.061,
#   'type': 'audio_features',
#   'id': '5s78Y4ulsGO9BJh5s3GrL9',
#   'uri': 'spotify:track:5s78Y4ulsGO9BJh5s3GrL9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5s78Y4ulsGO9BJh5s3GrL9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5s78Y4ulsGO9BJh5s3GrL9',
#   'duration_ms': 231549,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.275,
#   'key': 5,
#   'loudness': -11.168,
#   'mode': 1,
#   'speechiness': 0.0246,
#   'acousticness': 0.861,
#   'instrumentalness': 0.924,
#   'liveness': 0.0972,
#   'valence': 0.0861,
#   'tempo': 89.982,
#   'type': 'audio_features',
#   'id': '4McullpiOd45TwEHlOISgs',
#   'uri': 'spotify:track:4McullpiOd45TwEHlOISgs',
#   'track_href': 'https://api.spotify.com/v1/tracks/4McullpiOd45TwEHlOISgs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4McullpiOd45TwEHlOISgs',
#   'duration_ms': 486278,
#   'time_signature': 4},
#  {'danceability': 0.675,
#   'energy': 0.464,
#   'key': 1,
#   'loudness': -9.277,
#   'mode': 1,
#   'speechiness': 0.151,
#   'acousticness': 0.0635,
#   'instrumentalness': 0.073,
#   'liveness': 0.0711,
#   'valence': 0.129,
#   'tempo': 79.55,
#   'type': 'audio_features',
#   'id': '7asyVbwQE7IbA3x2be7bdI',
#   'uri': 'spotify:track:7asyVbwQE7IbA3x2be7bdI',
#   'track_href': 'https://api.spotify.com/v1/tracks/7asyVbwQE7IbA3x2be7bdI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7asyVbwQE7IbA3x2be7bdI',
#   'duration_ms': 233785,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.669,
#   'key': 1,
#   'loudness': -5.544,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.00329,
#   'instrumentalness': 0.000169,
#   'liveness': 0.0403,
#   'valence': 0.539,
#   'tempo': 76.988,
#   'type': 'audio_features',
#   'id': '2N977oXVcbzWqT4m3U698h',
#   'uri': 'spotify:track:2N977oXVcbzWqT4m3U698h',
#   'track_href': 'https://api.spotify.com/v1/tracks/2N977oXVcbzWqT4m3U698h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2N977oXVcbzWqT4m3U698h',
#   'duration_ms': 214387,
#   'time_signature': 4},
#  {'danceability': 0.253,
#   'energy': 0.298,
#   'key': 3,
#   'loudness': -7.583,
#   'mode': 0,
#   'speechiness': 0.0294,
#   'acousticness': 0.29,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'valence': 0.103,
#   'tempo': 139.722,
#   'type': 'audio_features',
#   'id': '2H3HPGuPyhcbg5AqoQ4BWr',
#   'uri': 'spotify:track:2H3HPGuPyhcbg5AqoQ4BWr',
#   'track_href': 'https://api.spotify.com/v1/tracks/2H3HPGuPyhcbg5AqoQ4BWr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2H3HPGuPyhcbg5AqoQ4BWr',
#   'duration_ms': 226460,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.285,
#   'key': 11,
#   'loudness': -15.103,
#   'mode': 0,
#   'speechiness': 0.0319,
#   'acousticness': 0.877,
#   'instrumentalness': 0.0126,
#   'liveness': 0.137,
#   'valence': 0.284,
#   'tempo': 107.14,
#   'type': 'audio_features',
#   'id': '3h9T2wLTy4FEKulLDkUjlX',
#   'uri': 'spotify:track:3h9T2wLTy4FEKulLDkUjlX',
#   'track_href': 'https://api.spotify.com/v1/tracks/3h9T2wLTy4FEKulLDkUjlX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3h9T2wLTy4FEKulLDkUjlX',
#   'duration_ms': 330747,
#   'time_signature': 4},
#  {'danceability': 0.498,
#   'energy': 0.432,
#   'key': 3,
#   'loudness': -7.297,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.888,
#   'instrumentalness': 0.617,
#   'liveness': 0.136,
#   'valence': 0.126,
#   'tempo': 132.928,
#   'type': 'audio_features',
#   'id': '68i41spJIphl0RDfDf7tOL',
#   'uri': 'spotify:track:68i41spJIphl0RDfDf7tOL',
#   'track_href': 'https://api.spotify.com/v1/tracks/68i41spJIphl0RDfDf7tOL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68i41spJIphl0RDfDf7tOL',
#   'duration_ms': 235053,
#   'time_signature': 4},
#  {'danceability': 0.498,
#   'energy': 0.557,
#   'key': 0,
#   'loudness': -7.644,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.0436,
#   'instrumentalness': 1.03e-05,
#   'liveness': 0.107,
#   'valence': 0.297,
#   'tempo': 117.092,
#   'type': 'audio_features',
#   'id': '53GQ3LEVNSFjGY891qyD85',
#   'uri': 'spotify:track:53GQ3LEVNSFjGY891qyD85',
#   'track_href': 'https://api.spotify.com/v1/tracks/53GQ3LEVNSFjGY891qyD85',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53GQ3LEVNSFjGY891qyD85',
#   'duration_ms': 251840,
#   'time_signature': 4},
#  {'danceability': 0.624,
#   'energy': 0.824,
#   'key': 6,
#   'loudness': -5.501,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 0.0167,
#   'instrumentalness': 0.00029,
#   'liveness': 0.138,
#   'valence': 0.366,
#   'tempo': 97.012,
#   'type': 'audio_features',
#   'id': '6uJwPeBGb3swi85TSr9iIz',
#   'uri': 'spotify:track:6uJwPeBGb3swi85TSr9iIz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6uJwPeBGb3swi85TSr9iIz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uJwPeBGb3swi85TSr9iIz',
#   'duration_ms': 276907,
#   'time_signature': 4},
#  {'danceability': 0.283,
#   'energy': 0.305,
#   'key': 9,
#   'loudness': -13.961,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.961,
#   'instrumentalness': 0.252,
#   'liveness': 0.0946,
#   'valence': 0.119,
#   'tempo': 104.126,
#   'type': 'audio_features',
#   'id': '2BEIajgcV26uakjqmPKd8w',
#   'uri': 'spotify:track:2BEIajgcV26uakjqmPKd8w',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BEIajgcV26uakjqmPKd8w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BEIajgcV26uakjqmPKd8w',
#   'duration_ms': 263747,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.405,
#   'key': 2,
#   'loudness': -8.067,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.18,
#   'instrumentalness': 0.635,
#   'liveness': 0.136,
#   'valence': 0.122,
#   'tempo': 104.952,
#   'type': 'audio_features',
#   'id': '0Y5yk0rKr64UdzeqG1nSI7',
#   'uri': 'spotify:track:0Y5yk0rKr64UdzeqG1nSI7',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Y5yk0rKr64UdzeqG1nSI7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Y5yk0rKr64UdzeqG1nSI7',
#   'duration_ms': 272571,
#   'time_signature': 3},
#  {'danceability': 0.398,
#   'energy': 0.425,
#   'key': 6,
#   'loudness': -8.566,
#   'mode': 0,
#   'speechiness': 0.0291,
#   'acousticness': 0.017,
#   'instrumentalness': 2.31e-05,
#   'liveness': 0.169,
#   'valence': 0.277,
#   'tempo': 76.246,
#   'type': 'audio_features',
#   'id': '5T3zvd5EWehdLG1PvtfIMy',
#   'uri': 'spotify:track:5T3zvd5EWehdLG1PvtfIMy',
#   'track_href': 'https://api.spotify.com/v1/tracks/5T3zvd5EWehdLG1PvtfIMy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5T3zvd5EWehdLG1PvtfIMy',
#   'duration_ms': 208305,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.19,
#   'key': 2,
#   'loudness': -14.961,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.903,
#   'instrumentalness': 0.000227,
#   'liveness': 0.0993,
#   'valence': 0.299,
#   'tempo': 100.002,
#   'type': 'audio_features',
#   'id': '5OHbgQbHzTjolHzWffSrvn',
#   'uri': 'spotify:track:5OHbgQbHzTjolHzWffSrvn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OHbgQbHzTjolHzWffSrvn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OHbgQbHzTjolHzWffSrvn',
#   'duration_ms': 239653,
#   'time_signature': 4},
#  {'danceability': 0.672,
#   'energy': 0.25,
#   'key': 8,
#   'loudness': -13.178,
#   'mode': 1,
#   'speechiness': 0.0426,
#   'acousticness': 0.493,
#   'instrumentalness': 0,
#   'liveness': 0.271,
#   'valence': 0.534,
#   'tempo': 83.997,
#   'type': 'audio_features',
#   'id': '42iNQtnKOBSn3YQebjQApn',
#   'uri': 'spotify:track:42iNQtnKOBSn3YQebjQApn',
#   'track_href': 'https://api.spotify.com/v1/tracks/42iNQtnKOBSn3YQebjQApn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42iNQtnKOBSn3YQebjQApn',
#   'duration_ms': 232679,
#   'time_signature': 4},
#  {'danceability': 0.576,
#   'energy': 0.457,
#   'key': 0,
#   'loudness': -6.473,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.143,
#   'instrumentalness': 3.05e-05,
#   'liveness': 0.0917,
#   'valence': 0.301,
#   'tempo': 138.984,
#   'type': 'audio_features',
#   'id': '0rzaRSujxA0bKyjJl6vHYq',
#   'uri': 'spotify:track:0rzaRSujxA0bKyjJl6vHYq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rzaRSujxA0bKyjJl6vHYq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rzaRSujxA0bKyjJl6vHYq',
#   'duration_ms': 218577,
#   'time_signature': 4},
#  {'danceability': 0.231,
#   'energy': 0.877,
#   'key': 9,
#   'loudness': -5.278,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.000653,
#   'instrumentalness': 0.026,
#   'liveness': 0.0694,
#   'valence': 0.524,
#   'tempo': 186.142,
#   'type': 'audio_features',
#   'id': '77G0k1La0c5Dw8bAFANcyp',
#   'uri': 'spotify:track:77G0k1La0c5Dw8bAFANcyp',
#   'track_href': 'https://api.spotify.com/v1/tracks/77G0k1La0c5Dw8bAFANcyp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77G0k1La0c5Dw8bAFANcyp',
#   'duration_ms': 164165,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.544,
#   'key': 7,
#   'loudness': -7.252,
#   'mode': 1,
#   'speechiness': 0.0297,
#   'acousticness': 0.0531,
#   'instrumentalness': 6.73e-05,
#   'liveness': 0.294,
#   'valence': 0.219,
#   'tempo': 125.992,
#   'type': 'audio_features',
#   'id': '15ZBpYcjtqCaD7EKCQ7tdN',
#   'uri': 'spotify:track:15ZBpYcjtqCaD7EKCQ7tdN',
#   'track_href': 'https://api.spotify.com/v1/tracks/15ZBpYcjtqCaD7EKCQ7tdN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15ZBpYcjtqCaD7EKCQ7tdN',
#   'duration_ms': 260000,
#   'time_signature': 3},
#  {'danceability': 0.492,
#   'energy': 0.59,
#   'key': 4,
#   'loudness': -4.032,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.00109,
#   'instrumentalness': 0.0023,
#   'liveness': 0.271,
#   'valence': 0.179,
#   'tempo': 117.637,
#   'type': 'audio_features',
#   'id': '2Tg7Tc4H50u11aDpmSRQTB',
#   'uri': 'spotify:track:2Tg7Tc4H50u11aDpmSRQTB',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Tg7Tc4H50u11aDpmSRQTB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tg7Tc4H50u11aDpmSRQTB',
#   'duration_ms': 229517,
#   'time_signature': 4},
#  {'danceability': 0.352,
#   'energy': 0.911,
#   'key': 1,
#   'loudness': -5.23,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.00121,
#   'instrumentalness': 0,
#   'liveness': 0.0995,
#   'valence': 0.236,
#   'tempo': 148.033,
#   'type': 'audio_features',
#   'id': '003vvx7Niy0yvhvHt4a68B',
#   'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B',
#   'track_href': 'https://api.spotify.com/v1/tracks/003vvx7Niy0yvhvHt4a68B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/003vvx7Niy0yvhvHt4a68B',
#   'duration_ms': 222973,
#   'time_signature': 4},
#  {'danceability': 0.394,
#   'energy': 0.256,
#   'key': 1,
#   'loudness': -14.683,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.117,
#   'instrumentalness': 0.00138,
#   'liveness': 0.154,
#   'valence': 0.0695,
#   'tempo': 140.373,
#   'type': 'audio_features',
#   'id': '5RL3Bec5a1QbdCBIoomJAJ',
#   'uri': 'spotify:track:5RL3Bec5a1QbdCBIoomJAJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RL3Bec5a1QbdCBIoomJAJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RL3Bec5a1QbdCBIoomJAJ',
#   'duration_ms': 283024,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.495,
#   'key': 10,
#   'loudness': -6.662,
#   'mode': 1,
#   'speechiness': 0.0343,
#   'acousticness': 0.659,
#   'instrumentalness': 0,
#   'liveness': 0.0754,
#   'valence': 0.308,
#   'tempo': 124.936,
#   'type': 'audio_features',
#   'id': '4U45aEWtQhrm8A5mxPaFZ7',
#   'uri': 'spotify:track:4U45aEWtQhrm8A5mxPaFZ7',
#   'track_href': 'https://api.spotify.com/v1/tracks/4U45aEWtQhrm8A5mxPaFZ7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4U45aEWtQhrm8A5mxPaFZ7',
#   'duration_ms': 214240,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.769,
#   'key': 4,
#   'loudness': -5.855,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.04,
#   'instrumentalness': 0,
#   'liveness': 0.136,
#   'valence': 0.876,
#   'tempo': 136.162,
#   'type': 'audio_features',
#   'id': '0WQiDwKJclirSYG9v5tayI',
#   'uri': 'spotify:track:0WQiDwKJclirSYG9v5tayI',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WQiDwKJclirSYG9v5tayI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WQiDwKJclirSYG9v5tayI',
#   'duration_ms': 244587,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.411,
#   'key': 11,
#   'loudness': -9.857,
#   'mode': 0,
#   'speechiness': 0.0386,
#   'acousticness': 0.25,
#   'instrumentalness': 0.00981,
#   'liveness': 0.162,
#   'valence': 0.353,
#   'tempo': 69.995,
#   'type': 'audio_features',
#   'id': '6lt8Z886tMHpNqzOFWX8Yn',
#   'uri': 'spotify:track:6lt8Z886tMHpNqzOFWX8Yn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6lt8Z886tMHpNqzOFWX8Yn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lt8Z886tMHpNqzOFWX8Yn',
#   'duration_ms': 169806,
#   'time_signature': 3},
#  {'danceability': 0.437,
#   'energy': 0.94,
#   'key': 9,
#   'loudness': -6.946,
#   'mode': 1,
#   'speechiness': 0.0426,
#   'acousticness': 0.0524,
#   'instrumentalness': 0.000573,
#   'liveness': 0.222,
#   'valence': 0.48,
#   'tempo': 151.417,
#   'type': 'audio_features',
#   'id': '4NnWuGQujzWUEg0uZokO5M',
#   'uri': 'spotify:track:4NnWuGQujzWUEg0uZokO5M',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NnWuGQujzWUEg0uZokO5M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NnWuGQujzWUEg0uZokO5M',
#   'duration_ms': 212013,
#   'time_signature': 4},
#  {'danceability': 0.188,
#   'energy': 0.675,
#   'key': 6,
#   'loudness': -6.188,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.206,
#   'instrumentalness': 0.0962,
#   'liveness': 0.662,
#   'valence': 0.617,
#   'tempo': 70.682,
#   'type': 'audio_features',
#   'id': '0jcHQTvfHCH1LETpdMdHJo',
#   'uri': 'spotify:track:0jcHQTvfHCH1LETpdMdHJo',
#   'track_href': 'https://api.spotify.com/v1/tracks/0jcHQTvfHCH1LETpdMdHJo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jcHQTvfHCH1LETpdMdHJo',
#   'duration_ms': 219227,
#   'time_signature': 4},
#  {'danceability': 0.668,
#   'energy': 0.484,
#   'key': 7,
#   'loudness': -9.289,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.449,
#   'instrumentalness': 0.51,
#   'liveness': 0.197,
#   'valence': 0.113,
#   'tempo': 125.103,
#   'type': 'audio_features',
#   'id': '0h3CnJ0DLrVcxggoDBDcNR',
#   'uri': 'spotify:track:0h3CnJ0DLrVcxggoDBDcNR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0h3CnJ0DLrVcxggoDBDcNR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0h3CnJ0DLrVcxggoDBDcNR',
#   'duration_ms': 334053,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.0488,
#   'key': 2,
#   'loudness': -18.962,
#   'mode': 1,
#   'speechiness': 0.061,
#   'acousticness': 0.949,
#   'instrumentalness': 0.000513,
#   'liveness': 0.131,
#   'valence': 0.101,
#   'tempo': 114.685,
#   'type': 'audio_features',
#   'id': '1fTLCNwEA63uyyr93xiZjm',
#   'uri': 'spotify:track:1fTLCNwEA63uyyr93xiZjm',
#   'track_href': 'https://api.spotify.com/v1/tracks/1fTLCNwEA63uyyr93xiZjm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1fTLCNwEA63uyyr93xiZjm',
#   'duration_ms': 209271,
#   'time_signature': 4},
#  {'danceability': 0.456,
#   'energy': 0.59,
#   'key': 11,
#   'loudness': -8.638,
#   'mode': 1,
#   'speechiness': 0.0327,
#   'acousticness': 0.00182,
#   'instrumentalness': 0.00379,
#   'liveness': 0.104,
#   'valence': 0.243,
#   'tempo': 124.635,
#   'type': 'audio_features',
#   'id': '2N2yrmodOnVF10mKvItC9P',
#   'uri': 'spotify:track:2N2yrmodOnVF10mKvItC9P',
#   'track_href': 'https://api.spotify.com/v1/tracks/2N2yrmodOnVF10mKvItC9P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2N2yrmodOnVF10mKvItC9P',
#   'duration_ms': 283733,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.202,
#   'key': 0,
#   'loudness': -10.976,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.935,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.323,
#   'tempo': 118.029,
#   'type': 'audio_features',
#   'id': '6qj02zSeEJGWZ4c0dn5QzJ',
#   'uri': 'spotify:track:6qj02zSeEJGWZ4c0dn5QzJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6qj02zSeEJGWZ4c0dn5QzJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qj02zSeEJGWZ4c0dn5QzJ',
#   'duration_ms': 194544,
#   'time_signature': 4},
#  {'danceability': 0.255,
#   'energy': 0.161,
#   'key': 9,
#   'loudness': -12.711,
#   'mode': 0,
#   'speechiness': 0.0327,
#   'acousticness': 0.925,
#   'instrumentalness': 0.0155,
#   'liveness': 0.147,
#   'valence': 0.0679,
#   'tempo': 74.007,
#   'type': 'audio_features',
#   'id': '0LHMAiZXmYy97d23W2O8f4',
#   'uri': 'spotify:track:0LHMAiZXmYy97d23W2O8f4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0LHMAiZXmYy97d23W2O8f4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LHMAiZXmYy97d23W2O8f4',
#   'duration_ms': 309720,
#   'time_signature': 4},
#  {'danceability': 0.411,
#   'energy': 0.0595,
#   'key': 3,
#   'loudness': -15.542,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.974,
#   'instrumentalness': 1.27e-05,
#   'liveness': 0.185,
#   'valence': 0.134,
#   'tempo': 78.56,
#   'type': 'audio_features',
#   'id': '2i7XH68YyqN2pe1Om3rxsi',
#   'uri': 'spotify:track:2i7XH68YyqN2pe1Om3rxsi',
#   'track_href': 'https://api.spotify.com/v1/tracks/2i7XH68YyqN2pe1Om3rxsi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2i7XH68YyqN2pe1Om3rxsi',
#   'duration_ms': 272041,
#   'time_signature': 3},
#  {'danceability': 0.339,
#   'energy': 0.43,
#   'key': 0,
#   'loudness': -10.102,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.667,
#   'instrumentalness': 0.0312,
#   'liveness': 0.253,
#   'valence': 0.126,
#   'tempo': 105.236,
#   'type': 'audio_features',
#   'id': '4FlR1nTr96hy7HK4OxY3aG',
#   'uri': 'spotify:track:4FlR1nTr96hy7HK4OxY3aG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FlR1nTr96hy7HK4OxY3aG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FlR1nTr96hy7HK4OxY3aG',
#   'duration_ms': 293267,
#   'time_signature': 4},
#  {'danceability': 0.535,
#   'energy': 0.448,
#   'key': 2,
#   'loudness': -9.167,
#   'mode': 1,
#   'speechiness': 0.0279,
#   'acousticness': 0.00262,
#   'instrumentalness': 1.94e-05,
#   'liveness': 0.115,
#   'valence': 0.32,
#   'tempo': 101.986,
#   'type': 'audio_features',
#   'id': '5411TEB6tlzvuF5A4oyldr',
#   'uri': 'spotify:track:5411TEB6tlzvuF5A4oyldr',
#   'track_href': 'https://api.spotify.com/v1/tracks/5411TEB6tlzvuF5A4oyldr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5411TEB6tlzvuF5A4oyldr',
#   'duration_ms': 149680,
#   'time_signature': 4},
#  {'danceability': 0.376,
#   'energy': 0.308,
#   'key': 4,
#   'loudness': -12.723,
#   'mode': 0,
#   'speechiness': 0.0309,
#   'acousticness': 0.315,
#   'instrumentalness': 0.0243,
#   'liveness': 0.117,
#   'valence': 0.0339,
#   'tempo': 134.158,
#   'type': 'audio_features',
#   'id': '62Uw5LOkCoBFvmrDBDe6UU',
#   'uri': 'spotify:track:62Uw5LOkCoBFvmrDBDe6UU',
#   'track_href': 'https://api.spotify.com/v1/tracks/62Uw5LOkCoBFvmrDBDe6UU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62Uw5LOkCoBFvmrDBDe6UU',
#   'duration_ms': 393240,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.826,
#   'key': 0,
#   'loudness': -5.487,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.0212,
#   'instrumentalness': 1.24e-05,
#   'liveness': 0.543,
#   'valence': 0.644,
#   'tempo': 118.051,
#   'type': 'audio_features',
#   'id': '5QO79kh1waicV47BqGRL3g',
#   'uri': 'spotify:track:5QO79kh1waicV47BqGRL3g',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QO79kh1waicV47BqGRL3g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QO79kh1waicV47BqGRL3g',
#   'duration_ms': 215627,
#   'time_signature': 4},
#  {'danceability': 0.49,
#   'energy': 0.48,
#   'key': 4,
#   'loudness': -9.089,
#   'mode': 0,
#   'speechiness': 0.0282,
#   'acousticness': 0.0551,
#   'instrumentalness': 0.935,
#   'liveness': 0.0896,
#   'valence': 0.115,
#   'tempo': 120.091,
#   'type': 'audio_features',
#   'id': '0RPJCrxg3zyex1xkui5DCO',
#   'uri': 'spotify:track:0RPJCrxg3zyex1xkui5DCO',
#   'track_href': 'https://api.spotify.com/v1/tracks/0RPJCrxg3zyex1xkui5DCO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RPJCrxg3zyex1xkui5DCO',
#   'duration_ms': 138000,
#   'time_signature': 4},
#  {'danceability': 0.321,
#   'energy': 0.52,
#   'key': 1,
#   'loudness': -9.521,
#   'mode': 0,
#   'speechiness': 0.0306,
#   'acousticness': 0.114,
#   'instrumentalness': 0.000351,
#   'liveness': 0.104,
#   'valence': 0.0927,
#   'tempo': 150.053,
#   'type': 'audio_features',
#   'id': '2899n1UyRzOmf41SmRGi6q',
#   'uri': 'spotify:track:2899n1UyRzOmf41SmRGi6q',
#   'track_href': 'https://api.spotify.com/v1/tracks/2899n1UyRzOmf41SmRGi6q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2899n1UyRzOmf41SmRGi6q',
#   'duration_ms': 263145,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.784,
#   'key': 6,
#   'loudness': -4.023,
#   'mode': 1,
#   'speechiness': 0.062,
#   'acousticness': 0.446,
#   'instrumentalness': 8.32e-06,
#   'liveness': 0.119,
#   'valence': 0.769,
#   'tempo': 172.041,
#   'type': 'audio_features',
#   'id': '3EaJDYHA0KnX88JvDhL9oa',
#   'uri': 'spotify:track:3EaJDYHA0KnX88JvDhL9oa',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EaJDYHA0KnX88JvDhL9oa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EaJDYHA0KnX88JvDhL9oa',
#   'duration_ms': 173104,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.371,
#   'key': 9,
#   'loudness': -11.575,
#   'mode': 0,
#   'speechiness': 0.0322,
#   'acousticness': 0.23,
#   'instrumentalness': 0,
#   'liveness': 0.0887,
#   'valence': 0.211,
#   'tempo': 120.01,
#   'type': 'audio_features',
#   'id': '1RgiH5ucgoEWDKmGyA5drQ',
#   'uri': 'spotify:track:1RgiH5ucgoEWDKmGyA5drQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1RgiH5ucgoEWDKmGyA5drQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RgiH5ucgoEWDKmGyA5drQ',
#   'duration_ms': 280371,
#   'time_signature': 4},
#  {'danceability': 0.279,
#   'energy': 0.627,
#   'key': 9,
#   'loudness': -9.419,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.0991,
#   'instrumentalness': 2.09e-06,
#   'liveness': 0.11,
#   'valence': 0.214,
#   'tempo': 97.051,
#   'type': 'audio_features',
#   'id': '5pcDlqgygjWQ75QYLM7mdL',
#   'uri': 'spotify:track:5pcDlqgygjWQ75QYLM7mdL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pcDlqgygjWQ75QYLM7mdL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pcDlqgygjWQ75QYLM7mdL',
#   'duration_ms': 246187,
#   'time_signature': 4},
#  {'danceability': 0.424,
#   'energy': 0.39,
#   'key': 0,
#   'loudness': -13.015,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.362,
#   'instrumentalness': 8.26e-06,
#   'liveness': 0.0961,
#   'valence': 0.282,
#   'tempo': 77.967,
#   'type': 'audio_features',
#   'id': '6NBqiBWNlfzOpvBMArCLEh',
#   'uri': 'spotify:track:6NBqiBWNlfzOpvBMArCLEh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NBqiBWNlfzOpvBMArCLEh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NBqiBWNlfzOpvBMArCLEh',
#   'duration_ms': 270014,
#   'time_signature': 4},
#  {'danceability': 0.456,
#   'energy': 0.44,
#   'key': 9,
#   'loudness': -7.796,
#   'mode': 1,
#   'speechiness': 0.0505,
#   'acousticness': 0.416,
#   'instrumentalness': 0.0152,
#   'liveness': 0.103,
#   'valence': 0.144,
#   'tempo': 120.036,
#   'type': 'audio_features',
#   'id': '49qhKNDnvA792NHeFwTKvk',
#   'uri': 'spotify:track:49qhKNDnvA792NHeFwTKvk',
#   'track_href': 'https://api.spotify.com/v1/tracks/49qhKNDnvA792NHeFwTKvk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49qhKNDnvA792NHeFwTKvk',
#   'duration_ms': 481347,
#   'time_signature': 4},
#  {'danceability': 0.484,
#   'energy': 0.135,
#   'key': 4,
#   'loudness': -18.825,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.897,
#   'instrumentalness': 0.567,
#   'liveness': 0.193,
#   'valence': 0.0385,
#   'tempo': 99.818,
#   'type': 'audio_features',
#   'id': '7pEXJL2XIu3VtgOac9nmz7',
#   'uri': 'spotify:track:7pEXJL2XIu3VtgOac9nmz7',
#   'track_href': 'https://api.spotify.com/v1/tracks/7pEXJL2XIu3VtgOac9nmz7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7pEXJL2XIu3VtgOac9nmz7',
#   'duration_ms': 194400,
#   'time_signature': 3},
#  {'danceability': 0.52,
#   'energy': 0.572,
#   'key': 6,
#   'loudness': -12.838,
#   'mode': 0,
#   'speechiness': 0.0402,
#   'acousticness': 0.352,
#   'instrumentalness': 0.947,
#   'liveness': 0.103,
#   'valence': 0.0985,
#   'tempo': 157.934,
#   'type': 'audio_features',
#   'id': '20Wh3jLHKWrbVpyZN2CgVa',
#   'uri': 'spotify:track:20Wh3jLHKWrbVpyZN2CgVa',
#   'track_href': 'https://api.spotify.com/v1/tracks/20Wh3jLHKWrbVpyZN2CgVa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20Wh3jLHKWrbVpyZN2CgVa',
#   'duration_ms': 136400,
#   'time_signature': 3},
#  {'danceability': 0.417,
#   'energy': 0.329,
#   'key': 6,
#   'loudness': -14.817,
#   'mode': 0,
#   'speechiness': 0.033,
#   'acousticness': 0.702,
#   'instrumentalness': 0.91,
#   'liveness': 0.125,
#   'valence': 0.0396,
#   'tempo': 141.992,
#   'type': 'audio_features',
#   'id': '1jYhmB4lXOdsOeD3p0CAoD',
#   'uri': 'spotify:track:1jYhmB4lXOdsOeD3p0CAoD',
#   'track_href': 'https://api.spotify.com/v1/tracks/1jYhmB4lXOdsOeD3p0CAoD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jYhmB4lXOdsOeD3p0CAoD',
#   'duration_ms': 350333,
#   'time_signature': 4},
#  {'danceability': 0.386,
#   'energy': 0.445,
#   'key': 11,
#   'loudness': -11.713,
#   'mode': 0,
#   'speechiness': 0.0377,
#   'acousticness': 0.606,
#   'instrumentalness': 0.000243,
#   'liveness': 0.702,
#   'valence': 0.188,
#   'tempo': 77.881,
#   'type': 'audio_features',
#   'id': '5YwVDOWMKH7T0KtvpPSESQ',
#   'uri': 'spotify:track:5YwVDOWMKH7T0KtvpPSESQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YwVDOWMKH7T0KtvpPSESQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YwVDOWMKH7T0KtvpPSESQ',
#   'duration_ms': 239267,
#   'time_signature': 4},
#  {'danceability': 0.549,
#   'energy': 0.446,
#   'key': 0,
#   'loudness': -10.852,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.714,
#   'instrumentalness': 0.244,
#   'liveness': 0.113,
#   'valence': 0.195,
#   'tempo': 119.928,
#   'type': 'audio_features',
#   'id': '7AL20ktwYSpyWgwttZCuwU',
#   'uri': 'spotify:track:7AL20ktwYSpyWgwttZCuwU',
#   'track_href': 'https://api.spotify.com/v1/tracks/7AL20ktwYSpyWgwttZCuwU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7AL20ktwYSpyWgwttZCuwU',
#   'duration_ms': 287000,
#   'time_signature': 4},
#  {'danceability': 0.412,
#   'energy': 0.473,
#   'key': 7,
#   'loudness': -6.983,
#   'mode': 1,
#   'speechiness': 0.0262,
#   'acousticness': 0.763,
#   'instrumentalness': 0.368,
#   'liveness': 0.206,
#   'valence': 0.237,
#   'tempo': 77.918,
#   'type': 'audio_features',
#   'id': '3SLlqKXr91haZQhhNYNuVk',
#   'uri': 'spotify:track:3SLlqKXr91haZQhhNYNuVk',
#   'track_href': 'https://api.spotify.com/v1/tracks/3SLlqKXr91haZQhhNYNuVk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SLlqKXr91haZQhhNYNuVk',
#   'duration_ms': 271000,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.0948,
#   'key': 10,
#   'loudness': -19.846,
#   'mode': 0,
#   'speechiness': 0.035,
#   'acousticness': 0.996,
#   'instrumentalness': 0.782,
#   'liveness': 0.0887,
#   'valence': 0.158,
#   'tempo': 77.818,
#   'type': 'audio_features',
#   'id': '62aaJpv0hPmj7HMc21zKwW',
#   'uri': 'spotify:track:62aaJpv0hPmj7HMc21zKwW',
#   'track_href': 'https://api.spotify.com/v1/tracks/62aaJpv0hPmj7HMc21zKwW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62aaJpv0hPmj7HMc21zKwW',
#   'duration_ms': 120962,
#   'time_signature': 4},
#  {'danceability': 0.397,
#   'energy': 0.397,
#   'key': 9,
#   'loudness': -12.374,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.492,
#   'instrumentalness': 0.901,
#   'liveness': 0.106,
#   'valence': 0.147,
#   'tempo': 74.91,
#   'type': 'audio_features',
#   'id': '4CWpax3A8UUUdcBe7Ivgkf',
#   'uri': 'spotify:track:4CWpax3A8UUUdcBe7Ivgkf',
#   'track_href': 'https://api.spotify.com/v1/tracks/4CWpax3A8UUUdcBe7Ivgkf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CWpax3A8UUUdcBe7Ivgkf',
#   'duration_ms': 225200,
#   'time_signature': 4},
#  {'danceability': 0.318,
#   'energy': 0.433,
#   'key': 7,
#   'loudness': -8.457,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.581,
#   'instrumentalness': 0.332,
#   'liveness': 0.235,
#   'valence': 0.135,
#   'tempo': 141.446,
#   'type': 'audio_features',
#   'id': '7Mstz10xsiP3vhIPzeSJlw',
#   'uri': 'spotify:track:7Mstz10xsiP3vhIPzeSJlw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Mstz10xsiP3vhIPzeSJlw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Mstz10xsiP3vhIPzeSJlw',
#   'duration_ms': 336500,
#   'time_signature': 3},
#  {'danceability': 0.704,
#   'energy': 0.232,
#   'key': 1,
#   'loudness': -12.038,
#   'mode': 0,
#   'speechiness': 0.0285,
#   'acousticness': 0.766,
#   'instrumentalness': 0.0268,
#   'liveness': 0.098,
#   'valence': 0.102,
#   'tempo': 121.035,
#   'type': 'audio_features',
#   'id': '7ykoMxLreMQ5pmIHV9hVmP',
#   'uri': 'spotify:track:7ykoMxLreMQ5pmIHV9hVmP',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ykoMxLreMQ5pmIHV9hVmP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ykoMxLreMQ5pmIHV9hVmP',
#   'duration_ms': 327541,
#   'time_signature': 4},
#  {'danceability': 0.621,
#   'energy': 0.713,
#   'key': 10,
#   'loudness': -7.226,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.605,
#   'instrumentalness': 8.28e-06,
#   'liveness': 0.103,
#   'valence': 0.609,
#   'tempo': 78.022,
#   'type': 'audio_features',
#   'id': '607EA1HsuzrqqaPuxyNqpD',
#   'uri': 'spotify:track:607EA1HsuzrqqaPuxyNqpD',
#   'track_href': 'https://api.spotify.com/v1/tracks/607EA1HsuzrqqaPuxyNqpD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/607EA1HsuzrqqaPuxyNqpD',
#   'duration_ms': 251627,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.407,
#   'key': 4,
#   'loudness': -6.947,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.633,
#   'instrumentalness': 0.000198,
#   'liveness': 0.0918,
#   'valence': 0.0922,
#   'tempo': 74.937,
#   'type': 'audio_features',
#   'id': '17xGX76BVzLRSbpYteAGR4',
#   'uri': 'spotify:track:17xGX76BVzLRSbpYteAGR4',
#   'track_href': 'https://api.spotify.com/v1/tracks/17xGX76BVzLRSbpYteAGR4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17xGX76BVzLRSbpYteAGR4',
#   'duration_ms': 278000,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.46,
#   'key': 6,
#   'loudness': -9.837,
#   'mode': 0,
#   'speechiness': 0.0604,
#   'acousticness': 0.754,
#   'instrumentalness': 0.637,
#   'liveness': 0.0869,
#   'valence': 0.149,
#   'tempo': 79.959,
#   'type': 'audio_features',
#   'id': '1sSqXPcyAUHe6eF3PTTEpL',
#   'uri': 'spotify:track:1sSqXPcyAUHe6eF3PTTEpL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sSqXPcyAUHe6eF3PTTEpL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sSqXPcyAUHe6eF3PTTEpL',
#   'duration_ms': 302264,
#   'time_signature': 4},
#  {'danceability': 0.46,
#   'energy': 0.47,
#   'key': 11,
#   'loudness': -9.703,
#   'mode': 0,
#   'speechiness': 0.0351,
#   'acousticness': 0.671,
#   'instrumentalness': 0.124,
#   'liveness': 0.0875,
#   'valence': 0.0898,
#   'tempo': 140.066,
#   'type': 'audio_features',
#   'id': '5HzHyCfkxFBbp4mZw56PUL',
#   'uri': 'spotify:track:5HzHyCfkxFBbp4mZw56PUL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HzHyCfkxFBbp4mZw56PUL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HzHyCfkxFBbp4mZw56PUL',
#   'duration_ms': 259855,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.461,
#   'key': 1,
#   'loudness': -7.94,
#   'mode': 0,
#   'speechiness': 0.0274,
#   'acousticness': 0.368,
#   'instrumentalness': 0.00115,
#   'liveness': 0.358,
#   'valence': 0.188,
#   'tempo': 131.325,
#   'type': 'audio_features',
#   'id': '51EMSRpNm9Rg5rGViVCczv',
#   'uri': 'spotify:track:51EMSRpNm9Rg5rGViVCczv',
#   'track_href': 'https://api.spotify.com/v1/tracks/51EMSRpNm9Rg5rGViVCczv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51EMSRpNm9Rg5rGViVCczv',
#   'duration_ms': 280187,
#   'time_signature': 4},
#  {'danceability': 0.628,
#   'energy': 0.5,
#   'key': 6,
#   'loudness': -9.66,
#   'mode': 0,
#   'speechiness': 0.0268,
#   'acousticness': 0.44,
#   'instrumentalness': 0,
#   'liveness': 0.244,
#   'valence': 0.68,
#   'tempo': 124.932,
#   'type': 'audio_features',
#   'id': '0GegHVxeozw3rdjte45Bfx',
#   'uri': 'spotify:track:0GegHVxeozw3rdjte45Bfx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0GegHVxeozw3rdjte45Bfx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0GegHVxeozw3rdjte45Bfx',
#   'duration_ms': 147027,
#   'time_signature': 4},
#  {'danceability': 0.3,
#   'energy': 0.452,
#   'key': 11,
#   'loudness': -9.298,
#   'mode': 1,
#   'speechiness': 0.0305,
#   'acousticness': 0.395,
#   'instrumentalness': 0.000834,
#   'liveness': 0.137,
#   'valence': 0.342,
#   'tempo': 82.985,
#   'type': 'audio_features',
#   'id': '2s7pyee9w04uQy3cNKzey9',
#   'uri': 'spotify:track:2s7pyee9w04uQy3cNKzey9',
#   'track_href': 'https://api.spotify.com/v1/tracks/2s7pyee9w04uQy3cNKzey9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2s7pyee9w04uQy3cNKzey9',
#   'duration_ms': 275307,
#   'time_signature': 4},
#  {'danceability': 0.802,
#   'energy': 0.41,
#   'key': 9,
#   'loudness': -12.793,
#   'mode': 1,
#   'speechiness': 0.0454,
#   'acousticness': 0.411,
#   'instrumentalness': 0.00107,
#   'liveness': 0.0941,
#   'valence': 0.224,
#   'tempo': 106.047,
#   'type': 'audio_features',
#   'id': '08bo51XXjxoJRv3O9tuUaj',
#   'uri': 'spotify:track:08bo51XXjxoJRv3O9tuUaj',
#   'track_href': 'https://api.spotify.com/v1/tracks/08bo51XXjxoJRv3O9tuUaj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08bo51XXjxoJRv3O9tuUaj',
#   'duration_ms': 241547,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.59,
#   'key': 4,
#   'loudness': -4.032,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.00109,
#   'instrumentalness': 0.0023,
#   'liveness': 0.271,
#   'valence': 0.179,
#   'tempo': 117.637,
#   'type': 'audio_features',
#   'id': '2lCyQnftM6ptqC3vk7qeao',
#   'uri': 'spotify:track:2lCyQnftM6ptqC3vk7qeao',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lCyQnftM6ptqC3vk7qeao',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lCyQnftM6ptqC3vk7qeao',
#   'duration_ms': 229517,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.465,
#   'key': 9,
#   'loudness': -8.088,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.642,
#   'instrumentalness': 0.039,
#   'liveness': 0.0637,
#   'valence': 0.359,
#   'tempo': 115.037,
#   'type': 'audio_features',
#   'id': '1TQPsGG43vZTqPhWoa95HR',
#   'uri': 'spotify:track:1TQPsGG43vZTqPhWoa95HR',
#   'track_href': 'https://api.spotify.com/v1/tracks/1TQPsGG43vZTqPhWoa95HR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1TQPsGG43vZTqPhWoa95HR',
#   'duration_ms': 185107,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.33,
#   'key': 11,
#   'loudness': -16.483,
#   'mode': 0,
#   'speechiness': 0.0434,
#   'acousticness': 0.822,
#   'instrumentalness': 0.293,
#   'liveness': 0.152,
#   'valence': 0.17,
#   'tempo': 135.034,
#   'type': 'audio_features',
#   'id': '2t2OCzf1X0wO34FPi31DME',
#   'uri': 'spotify:track:2t2OCzf1X0wO34FPi31DME',
#   'track_href': 'https://api.spotify.com/v1/tracks/2t2OCzf1X0wO34FPi31DME',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2t2OCzf1X0wO34FPi31DME',
#   'duration_ms': 337660,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.413,
#   'key': 9,
#   'loudness': -11.356,
#   'mode': 0,
#   'speechiness': 0.0292,
#   'acousticness': 0.934,
#   'instrumentalness': 0.262,
#   'liveness': 0.114,
#   'valence': 0.211,
#   'tempo': 122.127,
#   'type': 'audio_features',
#   'id': '1HYiZbH7QTKfOUe9AmvbJr',
#   'uri': 'spotify:track:1HYiZbH7QTKfOUe9AmvbJr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HYiZbH7QTKfOUe9AmvbJr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HYiZbH7QTKfOUe9AmvbJr',
#   'duration_ms': 230827,
#   'time_signature': 4},
#  {'danceability': 0.551,
#   'energy': 0.386,
#   'key': 0,
#   'loudness': -10.22,
#   'mode': 1,
#   'speechiness': 0.132,
#   'acousticness': 0.659,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.245,
#   'tempo': 116.409,
#   'type': 'audio_features',
#   'id': '3i5qVV8azKqGFK4Gzdt5YS',
#   'uri': 'spotify:track:3i5qVV8azKqGFK4Gzdt5YS',
#   'track_href': 'https://api.spotify.com/v1/tracks/3i5qVV8azKqGFK4Gzdt5YS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3i5qVV8azKqGFK4Gzdt5YS',
#   'duration_ms': 199387,
#   'time_signature': 1},
#  {'danceability': 0.728,
#   'energy': 0.456,
#   'key': 7,
#   'loudness': -7.93,
#   'mode': 1,
#   'speechiness': 0.0279,
#   'acousticness': 0.38,
#   'instrumentalness': 0.0467,
#   'liveness': 0.0855,
#   'valence': 0.136,
#   'tempo': 114.008,
#   'type': 'audio_features',
#   'id': '60u9WxwtzTagxLsuDLD6eC',
#   'uri': 'spotify:track:60u9WxwtzTagxLsuDLD6eC',
#   'track_href': 'https://api.spotify.com/v1/tracks/60u9WxwtzTagxLsuDLD6eC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60u9WxwtzTagxLsuDLD6eC',
#   'duration_ms': 275146,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.51,
#   'key': 6,
#   'loudness': -8.225,
#   'mode': 1,
#   'speechiness': 0.0462,
#   'acousticness': 0.755,
#   'instrumentalness': 0.105,
#   'liveness': 0.25,
#   'valence': 0.831,
#   'tempo': 142.01,
#   'type': 'audio_features',
#   'id': '79vEv8zqy9tLYsTxxkXHXq',
#   'uri': 'spotify:track:79vEv8zqy9tLYsTxxkXHXq',
#   'track_href': 'https://api.spotify.com/v1/tracks/79vEv8zqy9tLYsTxxkXHXq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/79vEv8zqy9tLYsTxxkXHXq',
#   'duration_ms': 260149,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.71,
#   'key': 7,
#   'loudness': -6.695,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'acousticness': 0.309,
#   'instrumentalness': 0.0139,
#   'liveness': 0.121,
#   'valence': 0.196,
#   'tempo': 119.971,
#   'type': 'audio_features',
#   'id': '46YPYKwArr3UU2ibCL921x',
#   'uri': 'spotify:track:46YPYKwArr3UU2ibCL921x',
#   'track_href': 'https://api.spotify.com/v1/tracks/46YPYKwArr3UU2ibCL921x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/46YPYKwArr3UU2ibCL921x',
#   'duration_ms': 253450,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.159,
#   'key': 8,
#   'loudness': -13.666,
#   'mode': 0,
#   'speechiness': 0.0345,
#   'acousticness': 0.876,
#   'instrumentalness': 0.124,
#   'liveness': 0.128,
#   'valence': 0.0738,
#   'tempo': 119.869,
#   'type': 'audio_features',
#   'id': '4CUyNgMxAFKFEf1KrbAEbY',
#   'uri': 'spotify:track:4CUyNgMxAFKFEf1KrbAEbY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4CUyNgMxAFKFEf1KrbAEbY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CUyNgMxAFKFEf1KrbAEbY',
#   'duration_ms': 153667,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.416,
#   'key': 0,
#   'loudness': -7.925,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.212,
#   'instrumentalness': 2.03e-05,
#   'liveness': 0.134,
#   'valence': 0.392,
#   'tempo': 136.199,
#   'type': 'audio_features',
#   'id': '6NxJzgFY4aW7vD310Sui2D',
#   'uri': 'spotify:track:6NxJzgFY4aW7vD310Sui2D',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NxJzgFY4aW7vD310Sui2D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NxJzgFY4aW7vD310Sui2D',
#   'duration_ms': 334903,
#   'time_signature': 4},
#  {'danceability': 0.536,
#   'energy': 0.311,
#   'key': 0,
#   'loudness': -11.59,
#   'mode': 1,
#   'speechiness': 0.0332,
#   'acousticness': 0.859,
#   'instrumentalness': 0.123,
#   'liveness': 0.125,
#   'valence': 0.0596,
#   'tempo': 113.019,
#   'type': 'audio_features',
#   'id': '3gKTFAmV6Ur7vSLmH3T659',
#   'uri': 'spotify:track:3gKTFAmV6Ur7vSLmH3T659',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gKTFAmV6Ur7vSLmH3T659',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gKTFAmV6Ur7vSLmH3T659',
#   'duration_ms': 255166,
#   'time_signature': 3},
#  {'danceability': 0.537,
#   'energy': 0.342,
#   'key': 4,
#   'loudness': -9.785,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.833,
#   'instrumentalness': 0.6,
#   'liveness': 0.0856,
#   'valence': 0.156,
#   'tempo': 128.331,
#   'type': 'audio_features',
#   'id': '5k7VKj1Xwy5DjO4B0PdAOb',
#   'uri': 'spotify:track:5k7VKj1Xwy5DjO4B0PdAOb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5k7VKj1Xwy5DjO4B0PdAOb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5k7VKj1Xwy5DjO4B0PdAOb',
#   'duration_ms': 255387,
#   'time_signature': 3},
#  {'danceability': 0.679,
#   'energy': 0.283,
#   'key': 0,
#   'loudness': -9.159,
#   'mode': 1,
#   'speechiness': 0.0328,
#   'acousticness': 0.0695,
#   'instrumentalness': 0.103,
#   'liveness': 0.0342,
#   'valence': 0.275,
#   'tempo': 77.036,
#   'type': 'audio_features',
#   'id': '1CaE0HSFy3ACitYvvGsh3h',
#   'uri': 'spotify:track:1CaE0HSFy3ACitYvvGsh3h',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CaE0HSFy3ACitYvvGsh3h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CaE0HSFy3ACitYvvGsh3h',
#   'duration_ms': 243973,
#   'time_signature': 4},
#  {'danceability': 0.322,
#   'energy': 0.112,
#   'key': 7,
#   'loudness': -15.676,
#   'mode': 0,
#   'speechiness': 0.0346,
#   'acousticness': 0.96,
#   'instrumentalness': 0.73,
#   'liveness': 0.461,
#   'valence': 0.149,
#   'tempo': 74.913,
#   'type': 'audio_features',
#   'id': '1UVJyTsRqca72fn1Dtwncv',
#   'uri': 'spotify:track:1UVJyTsRqca72fn1Dtwncv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UVJyTsRqca72fn1Dtwncv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UVJyTsRqca72fn1Dtwncv',
#   'duration_ms': 142832,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.378,
#   'key': 11,
#   'loudness': -10.381,
#   'mode': 0,
#   'speechiness': 0.0301,
#   'acousticness': 0.278,
#   'instrumentalness': 0.714,
#   'liveness': 0.102,
#   'valence': 0.0664,
#   'tempo': 68.26,
#   'type': 'audio_features',
#   'id': '4QOECnEv6cZzKLNfp65ytP',
#   'uri': 'spotify:track:4QOECnEv6cZzKLNfp65ytP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QOECnEv6cZzKLNfp65ytP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QOECnEv6cZzKLNfp65ytP',
#   'duration_ms': 270999,
#   'time_signature': 4},
#  {'danceability': 0.374,
#   'energy': 0.249,
#   'key': 1,
#   'loudness': -10.985,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.936,
#   'instrumentalness': 0.00876,
#   'liveness': 0.114,
#   'valence': 0.0633,
#   'tempo': 128.018,
#   'type': 'audio_features',
#   'id': '4eCXQY1vh9XMW66LmS5alP',
#   'uri': 'spotify:track:4eCXQY1vh9XMW66LmS5alP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eCXQY1vh9XMW66LmS5alP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eCXQY1vh9XMW66LmS5alP',
#   'duration_ms': 200093,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.362,
#   'key': 8,
#   'loudness': -13.062,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.433,
#   'instrumentalness': 0.00468,
#   'liveness': 0.0904,
#   'valence': 0.0995,
#   'tempo': 132.472,
#   'type': 'audio_features',
#   'id': '6UzdCUyZa27ez12pK56uSo',
#   'uri': 'spotify:track:6UzdCUyZa27ez12pK56uSo',
#   'track_href': 'https://api.spotify.com/v1/tracks/6UzdCUyZa27ez12pK56uSo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UzdCUyZa27ez12pK56uSo',
#   'duration_ms': 379653,
#   'time_signature': 4},
#  {'danceability': 0.401,
#   'energy': 0.567,
#   'key': 10,
#   'loudness': -9.131,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.171,
#   'instrumentalness': 0.00859,
#   'liveness': 0.103,
#   'valence': 0.362,
#   'tempo': 171.059,
#   'type': 'audio_features',
#   'id': '6FQcdl2PzmsoXRF3F1flZ5',
#   'uri': 'spotify:track:6FQcdl2PzmsoXRF3F1flZ5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6FQcdl2PzmsoXRF3F1flZ5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6FQcdl2PzmsoXRF3F1flZ5',
#   'duration_ms': 217973,
#   'time_signature': 3},
#  {'danceability': 0.626,
#   'energy': 0.308,
#   'key': 6,
#   'loudness': -17.163,
#   'mode': 0,
#   'speechiness': 0.0294,
#   'acousticness': 0.83,
#   'instrumentalness': 0.0578,
#   'liveness': 0.108,
#   'valence': 0.323,
#   'tempo': 129.928,
#   'type': 'audio_features',
#   'id': '5kkqN6Lx3ZioloqqxC7Kyj',
#   'uri': 'spotify:track:5kkqN6Lx3ZioloqqxC7Kyj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5kkqN6Lx3ZioloqqxC7Kyj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kkqN6Lx3ZioloqqxC7Kyj',
#   'duration_ms': 226890,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.478,
#   'key': 4,
#   'loudness': -8.689,
#   'mode': 0,
#   'speechiness': 0.0355,
#   'acousticness': 0.531,
#   'instrumentalness': 0.428,
#   'liveness': 0.138,
#   'valence': 0.0997,
#   'tempo': 88.014,
#   'type': 'audio_features',
#   'id': '5Qv2Nby1xTr9pQyjkrc94J',
#   'uri': 'spotify:track:5Qv2Nby1xTr9pQyjkrc94J',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9pQyjkrc94J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Qv2Nby1xTr9pQyjkrc94J',
#   'duration_ms': 228747,
#   'time_signature': 4}]

# %%
liked_df = pd.DataFrame(liked_features)
liked_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.271   0.165    5   -20.652     1       0.0351        0.7290
# 1          0.177   0.215    3    -9.886     1       0.0335        0.8070
# 2          0.530   0.497    0   -11.348     1       0.0322        0.4980
# 3          0.617   0.567    0    -4.188     1       0.0828        0.0584
# 4          0.214   0.367    6   -10.858     0       0.0321        0.8440
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.374   0.249    1   -10.985     1       0.0395        0.9360
# 96         0.588   0.362    8   -13.062     1       0.0295        0.4330
# 97         0.401   0.567   10    -9.131     1       0.0355        0.1710
# 98         0.626   0.308    6   -17.163     0       0.0294        0.8300
# 99         0.670   0.478    4    -8.689     0       0.0355        0.5310
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.1180   0.2030   77.082  audio_features
# 1           0.000125    0.0921   0.0415   75.862  audio_features
# 2           0.000384    0.0665   0.1000  141.977  audio_features
# 3           0.000000    0.0933   0.5050   90.246  audio_features
# 4           0.018100    0.1880   0.1750   79.854  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.008760    0.1140   0.0633  128.018  audio_features
# 96          0.004680    0.0904   0.0995  132.472  audio_features
# 97          0.008590    0.1030   0.3620  171.059  audio_features
# 98          0.057800    0.1080   0.3230  129.928  audio_features
# 99          0.428000    0.1380   0.0997   88.014  audio_features
#
#                         id                                   uri  \
# 0   29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1   2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2   5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3   1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4   1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                     ...                                   ...
# 95  4eCXQY1vh9XMW66LmS5alP  spotify:track:4eCXQY1vh9XMW66LmS5alP
# 96  6UzdCUyZa27ez12pK56uSo  spotify:track:6UzdCUyZa27ez12pK56uSo
# 97  6FQcdl2PzmsoXRF3F1flZ5  spotify:track:6FQcdl2PzmsoXRF3F1flZ5
# 98  5kkqN6Lx3ZioloqqxC7Kyj  spotify:track:5kkqN6Lx3ZioloqqxC7Kyj
# 99  5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1   https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2   https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3   https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4   https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4eCXQY1vh9XM...
# 96  https://api.spotify.com/v1/tracks/6UzdCUyZa27e...
# 97  https://api.spotify.com/v1/tracks/6FQcdl2Pzmso...
# 98  https://api.spotify.com/v1/tracks/5kkqN6Lx3Zio...
# 99  https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/29U7...       139227
# 1   https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 2   https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 3   https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 4   https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4eCX...       200093
# 96  https://api.spotify.com/v1/audio-analysis/6Uzd...       379653
# 97  https://api.spotify.com/v1/audio-analysis/6FQc...       217973
# 98  https://api.spotify.com/v1/audio-analysis/5kkq...       226890
# 99  https://api.spotify.com/v1/audio-analysis/5Qv2...       228747
#
#     time_signature
# 0                4
# 1                3
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               3
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
target = []

for i in range(liked_df.shape[0]):
    target.append(1)

# %%
liked_df['target'] = target
liked_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.271   0.165    5   -20.652     1       0.0351        0.7290
# 1          0.177   0.215    3    -9.886     1       0.0335        0.8070
# 2          0.530   0.497    0   -11.348     1       0.0322        0.4980
# 3          0.617   0.567    0    -4.188     1       0.0828        0.0584
# 4          0.214   0.367    6   -10.858     0       0.0321        0.8440
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.374   0.249    1   -10.985     1       0.0395        0.9360
# 96         0.588   0.362    8   -13.062     1       0.0295        0.4330
# 97         0.401   0.567   10    -9.131     1       0.0355        0.1710
# 98         0.626   0.308    6   -17.163     0       0.0294        0.8300
# 99         0.670   0.478    4    -8.689     0       0.0355        0.5310
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.1180   0.2030   77.082  audio_features
# 1           0.000125    0.0921   0.0415   75.862  audio_features
# 2           0.000384    0.0665   0.1000  141.977  audio_features
# 3           0.000000    0.0933   0.5050   90.246  audio_features
# 4           0.018100    0.1880   0.1750   79.854  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.008760    0.1140   0.0633  128.018  audio_features
# 96          0.004680    0.0904   0.0995  132.472  audio_features
# 97          0.008590    0.1030   0.3620  171.059  audio_features
# 98          0.057800    0.1080   0.3230  129.928  audio_features
# 99          0.428000    0.1380   0.0997   88.014  audio_features
#
#                         id                                   uri  \
# 0   29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1   2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2   5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3   1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4   1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                     ...                                   ...
# 95  4eCXQY1vh9XMW66LmS5alP  spotify:track:4eCXQY1vh9XMW66LmS5alP
# 96  6UzdCUyZa27ez12pK56uSo  spotify:track:6UzdCUyZa27ez12pK56uSo
# 97  6FQcdl2PzmsoXRF3F1flZ5  spotify:track:6FQcdl2PzmsoXRF3F1flZ5
# 98  5kkqN6Lx3ZioloqqxC7Kyj  spotify:track:5kkqN6Lx3ZioloqqxC7Kyj
# 99  5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1   https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2   https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3   https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4   https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4eCXQY1vh9XM...
# 96  https://api.spotify.com/v1/tracks/6UzdCUyZa27e...
# 97  https://api.spotify.com/v1/tracks/6FQcdl2Pzmso...
# 98  https://api.spotify.com/v1/tracks/5kkqN6Lx3Zio...
# 99  https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/29U7...       139227
# 1   https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 2   https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 3   https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 4   https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4eCX...       200093
# 96  https://api.spotify.com/v1/audio-analysis/6Uzd...       379653
# 97  https://api.spotify.com/v1/audio-analysis/6FQc...       217973
# 98  https://api.spotify.com/v1/audio-analysis/5kkq...       226890
# 99  https://api.spotify.com/v1/audio-analysis/5Qv2...       228747
#
#     time_signature  target
# 0                4       1
# 1                3       1
# 2                4       1
# 3                4       1
# 4                4       1
# ..             ...     ...
# 95               4       1
# 96               4       1
# 97               3       1
# 98               4       1
# 99               4       1
#
# [100 rows x 19 columns]

# %%
disliked_songs = playlist_d["tracks"]["items"] 
disliked_songs
# Out:
# []

# %%
disliked_ids = []
for i in range(len(disliked_songs)): 
    disliked_ids.append(disliked_songs[i]["track"]["id"])

# %%
disliked_features = sp.audio_features(disliked_ids) 

disliked_features
# Out:
# [None]

# %%
disliked_df = pd.DataFrame(disliked_features)
disliked_df
# Out:
#       0
# 0  None

# %%
liked_target = []

for i in range(disliked_df.shape[0]):
    liked_target.append(0)

# %%
disliked_df['target'] = liked_target
disliked_df
# Out:
#       0  target
# 0  None       0

# %%
#combining

frames = [liked_df, disliked_df]
  
result = pd.concat(frames).reset_index()
result
# Out:
#      index  danceability  energy   key  loudness  mode  speechiness  \
# 0        0         0.271   0.165   5.0   -20.652   1.0       0.0351
# 1        1         0.177   0.215   3.0    -9.886   1.0       0.0335
# 2        2         0.530   0.497   0.0   -11.348   1.0       0.0322
# 3        3         0.617   0.567   0.0    -4.188   1.0       0.0828
# 4        4         0.214   0.367   6.0   -10.858   0.0       0.0321
# ..     ...           ...     ...   ...       ...   ...          ...
# 96      96         0.588   0.362   8.0   -13.062   1.0       0.0295
# 97      97         0.401   0.567  10.0    -9.131   1.0       0.0355
# 98      98         0.626   0.308   6.0   -17.163   0.0       0.0294
# 99      99         0.670   0.478   4.0    -8.689   0.0       0.0355
# 100      0           NaN     NaN   NaN       NaN   NaN          NaN
#
#      acousticness  instrumentalness  liveness  ...    tempo            type  \
# 0          0.7290          0.000002    0.1180  ...   77.082  audio_features
# 1          0.8070          0.000125    0.0921  ...   75.862  audio_features
# 2          0.4980          0.000384    0.0665  ...  141.977  audio_features
# 3          0.0584          0.000000    0.0933  ...   90.246  audio_features
# 4          0.8440          0.018100    0.1880  ...   79.854  audio_features
# ..            ...               ...       ...  ...      ...             ...
# 96         0.4330          0.004680    0.0904  ...  132.472  audio_features
# 97         0.1710          0.008590    0.1030  ...  171.059  audio_features
# 98         0.8300          0.057800    0.1080  ...  129.928  audio_features
# 99         0.5310          0.428000    0.1380  ...   88.014  audio_features
# 100           NaN               NaN       NaN  ...      NaN             NaN
#
#                          id                                   uri  \
# 0    29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1    2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2    5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3    1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4    1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                      ...                                   ...
# 96   6UzdCUyZa27ez12pK56uSo  spotify:track:6UzdCUyZa27ez12pK56uSo
# 97   6FQcdl2PzmsoXRF3F1flZ5  spotify:track:6FQcdl2PzmsoXRF3F1flZ5
# 98   5kkqN6Lx3ZioloqqxC7Kyj  spotify:track:5kkqN6Lx3ZioloqqxC7Kyj
# 99   5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
# 100                     NaN                                   NaN
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1    https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2    https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3    https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4    https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                 ...
# 96   https://api.spotify.com/v1/tracks/6UzdCUyZa27e...
# 97   https://api.spotify.com/v1/tracks/6FQcdl2Pzmso...
# 98   https://api.spotify.com/v1/tracks/5kkqN6Lx3Zio...
# 99   https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
# 100                                                NaN
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/29U7...    139227.0
# 1    https://api.spotify.com/v1/audio-analysis/2Mfw...    188864.0
# 2    https://api.spotify.com/v1/audio-analysis/5b7w...    345933.0
# 3    https://api.spotify.com/v1/audio-analysis/1CnP...    217603.0
# 4    https://api.spotify.com/v1/audio-analysis/1M8O...    281844.0
# ..                                                 ...         ...
# 96   https://api.spotify.com/v1/audio-analysis/6Uzd...    379653.0
# 97   https://api.spotify.com/v1/audio-analysis/6FQc...    217973.0
# 98   https://api.spotify.com/v1/audio-analysis/5kkq...    226890.0
# 99   https://api.spotify.com/v1/audio-analysis/5Qv2...    228747.0
# 100                                                NaN         NaN
#
#      time_signature  target     0
# 0               4.0       1   NaN
# 1               3.0       1   NaN
# 2               4.0       1   NaN
# 3               4.0       1   NaN
# 4               4.0       1   NaN
# ..              ...     ...   ...
# 96              4.0       1   NaN
# 97              3.0       1   NaN
# 98              4.0       1   NaN
# 99              4.0       1   NaN
# 100             NaN       0  None
#
# [101 rows x 21 columns]

# %%
#shuffle
result = result.sample(frac = 1).reset_index()
result
# Out:
#      level_0  index  danceability  energy   key  loudness  mode  speechiness  \
# 0          5      5         0.236  0.1560   1.0   -16.973   0.0       0.0389
# 1         39     39         0.394  0.2560   1.0   -14.683   0.0       0.0313
# 2         74     74         0.508  0.4600   6.0    -9.837   0.0       0.0604
# 3         12     12         0.653  0.5050  10.0    -7.102   0.0       0.0261
# 4         31     31         0.398  0.4250   6.0    -8.566   0.0       0.0291
# ..       ...    ...           ...     ...   ...       ...   ...          ...
# 96        16     16         0.440  0.3170   8.0    -9.258   1.0       0.0531
# 97        99     99         0.670  0.4780   4.0    -8.689   0.0       0.0355
# 98        68     68         0.621  0.0948  10.0   -19.846   0.0       0.0350
# 99        48     48         0.417  0.2020   0.0   -10.976   1.0       0.0357
# 100       27     27         0.498  0.5570   0.0    -7.644   1.0       0.0280
#
#      acousticness  instrumentalness  ...    tempo            type  \
# 0          0.7310          0.000000  ...   85.780  audio_features
# 1          0.1170          0.001380  ...  140.373  audio_features
# 2          0.7540          0.637000  ...   79.959  audio_features
# 3          0.7660          0.000008  ...   96.109  audio_features
# 4          0.0170          0.000023  ...   76.246  audio_features
# ..            ...               ...  ...      ...             ...
# 96         0.8910          0.000005  ...  169.914  audio_features
# 97         0.5310          0.428000  ...   88.014  audio_features
# 98         0.9960          0.782000  ...   77.818  audio_features
# 99         0.9350          0.000000  ...  118.029  audio_features
# 100        0.0436          0.000010  ...  117.092  audio_features
#
#                          id                                   uri  \
# 0    20UK2eUwlRzNuW60gzITuj  spotify:track:20UK2eUwlRzNuW60gzITuj
# 1    5RL3Bec5a1QbdCBIoomJAJ  spotify:track:5RL3Bec5a1QbdCBIoomJAJ
# 2    1sSqXPcyAUHe6eF3PTTEpL  spotify:track:1sSqXPcyAUHe6eF3PTTEpL
# 3    7Dq7IjABZfw3LZDZRwPBEu  spotify:track:7Dq7IjABZfw3LZDZRwPBEu
# 4    5T3zvd5EWehdLG1PvtfIMy  spotify:track:5T3zvd5EWehdLG1PvtfIMy
# ..                      ...                                   ...
# 96   6xGruZOHLs39ZbVccQTuPZ  spotify:track:6xGruZOHLs39ZbVccQTuPZ
# 97   5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
# 98   62aaJpv0hPmj7HMc21zKwW  spotify:track:62aaJpv0hPmj7HMc21zKwW
# 99   6qj02zSeEJGWZ4c0dn5QzJ  spotify:track:6qj02zSeEJGWZ4c0dn5QzJ
# 100  53GQ3LEVNSFjGY891qyD85  spotify:track:53GQ3LEVNSFjGY891qyD85
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/20UK2eUwlRzN...
# 1    https://api.spotify.com/v1/tracks/5RL3Bec5a1Qb...
# 2    https://api.spotify.com/v1/tracks/1sSqXPcyAUHe...
# 3    https://api.spotify.com/v1/tracks/7Dq7IjABZfw3...
# 4    https://api.spotify.com/v1/tracks/5T3zvd5EWehd...
# ..                                                 ...
# 96   https://api.spotify.com/v1/tracks/6xGruZOHLs39...
# 97   https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
# 98   https://api.spotify.com/v1/tracks/62aaJpv0hPmj...
# 99   https://api.spotify.com/v1/tracks/6qj02zSeEJGW...
# 100  https://api.spotify.com/v1/tracks/53GQ3LEVNSFj...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/20UK...    161022.0
# 1    https://api.spotify.com/v1/audio-analysis/5RL3...    283024.0
# 2    https://api.spotify.com/v1/audio-analysis/1sSq...    302264.0
# 3    https://api.spotify.com/v1/audio-analysis/7Dq7...    228907.0
# 4    https://api.spotify.com/v1/audio-analysis/5T3z...    208305.0
# ..                                                 ...         ...
# 96   https://api.spotify.com/v1/audio-analysis/6xGr...    233456.0
# 97   https://api.spotify.com/v1/audio-analysis/5Qv2...    228747.0
# 98   https://api.spotify.com/v1/audio-analysis/62aa...    120962.0
# 99   https://api.spotify.com/v1/audio-analysis/6qj0...    194544.0
# 100  https://api.spotify.com/v1/audio-analysis/53GQ...    251840.0
#
#     time_signature  target    0
# 0              4.0       1  NaN
# 1              4.0       1  NaN
# 2              4.0       1  NaN
# 3              4.0       1  NaN
# 4              4.0       1  NaN
# ..             ...     ...  ...
# 96             3.0       1  NaN
# 97             4.0       1  NaN
# 98             4.0       1  NaN
# 99             4.0       1  NaN
# 100            4.0       1  NaN
#
# [101 rows x 22 columns]
