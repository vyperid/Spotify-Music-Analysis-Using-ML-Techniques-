# %% [markdown]
# <a href="https://colab.research.google.com/github/vyperid/Design-Project/blob/main/DatasetCreationFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install spotipy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.21.0-py3-none-any.whl (28 kB)
# Collecting redis>=3.5.3
#   Downloading redis-4.4.0-py3-none-any.whl (236 kB)
#      |████████████████████████████████| 236 kB 8.3 MB/s
# Collecting requests>=2.25.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spotipy) (1.15.0)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 58.7 MB/s
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (2022.9.24)
# Installing collected packages: urllib3, requests, redis, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed redis-4.4.0 requests-2.28.1 spotipy-2.21.0 urllib3-1.26.13

# %%
import pandas as pd 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials 
from collections import Counter

# %%
sp = spotipy.Spotify() 

cid ="userid" 

secret = "secretid"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 

sp.trace=False

# %%
playlist_l = sp.user_playlist("Liked", "3cYqEaPBFyxqlXbViPtzDv?si=3553c6c98f714847") 
playlist_d = sp.user_playlist("Disliked", "4HC1kIY2bof1CHfZqmo8u1?si=080494e8e1bf4f75") 

playlist_l
playlist_d
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/4HC1kIY2bof1CHfZqmo8u1'},
#  'followers': {'href': None, 'total': 1},
#  'href': 'https://api.spotify.com/v1/playlists/4HC1kIY2bof1CHfZqmo8u1?additional_types=track',
#  'id': '4HC1kIY2bof1CHfZqmo8u1',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b27386bd10366956a2c09e0904f7ab67616d0000b273936c6c5ac47f7fa1be5f4c59ab67616d0000b273ad7be7b2826352f0895ba7f7ab67616d0000b273cb6756b8f9a50234517ae7c4',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b27386bd10366956a2c09e0904f7ab67616d0000b273936c6c5ac47f7fa1be5f4c59ab67616d0000b273ad7be7b2826352f0895ba7f7ab67616d0000b273cb6756b8f9a50234517ae7c4',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b27386bd10366956a2c09e0904f7ab67616d0000b273936c6c5ac47f7fa1be5f4c59ab67616d0000b273ad7be7b2826352f0895ba7f7ab67616d0000b273cb6756b8f9a50234517ae7c4',
#    'width': 60}],
#  'name': 'Disliked',
#  'owner': {'display_name': 'demirbilekf',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#   'href': 'https://api.spotify.com/v1/users/bullseye012',
#   'id': 'bullseye012',
#   'type': 'user',
#   'uri': 'spotify:user:bullseye012'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MzcsN2Y4YjFhMGIyNzkwOTY5OWE5NDUxMzlmZGRjYTU0YTU0OWE2ZDQ4ZQ==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/4HC1kIY2bof1CHfZqmo8u1/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2022-12-05T19:39:13Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#         'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#         'id': '0sYlth2PW1zWJMEU2vCukz',
#         'name': 'Flower Face',
#         'type': 'artist',
#         'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/75nZGvjStgCUavXcsYsXf7'},
#       'href': 'https://api.spotify.com/v1/albums/75nZGvjStgCUavXcsYsXf7',
#       'id': '75nZGvjStgCUavXcsYsXf7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c5eb6ea693bf928ca3e13661',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c5eb6ea693bf928ca3e13661',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c5eb6ea693bf928ca3e13661',
#         'width': 64}],
#       'name': 'The Shark in Your Water',
#       'release_date': '2022-05-27',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:75nZGvjStgCUavXcsYsXf7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#        'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#        'id': '0sYlth2PW1zWJMEU2vCukz',
#        'name': 'Flower Face',
#        'type': 'artist',
#        'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 188864,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'CAN112100630'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2MfwT3SKUyF0na2LCa2fCp'},
#      'href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#      'id': '2MfwT3SKUyF0na2LCa2fCp',
#      'is_local': False,
#      'name': 'Cornflower Blue',
#      'popularity': 56,
#      'preview_url': 'https://p.scdn.co/mp3-preview/0ed6d70223d702345bc06dd471fea0674c867298?cid=d062190fd93b4e4488e75ae2d9256814',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:17Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#         'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#         'id': '53A0W3U0s8diEn9RhXQhVz',
#         'name': 'Keane',
#         'type': 'artist',
#         'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5QqVXRTiGpLgmo1YNoz9Bk'},
#       'href': 'https://api.spotify.com/v1/albums/5QqVXRTiGpLgmo1YNoz9Bk',
#       'id': '5QqVXRTiGpLgmo1YNoz9Bk',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273d1a0d9a7cf88083aac260c33',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02d1a0d9a7cf88083aac260c33',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851d1a0d9a7cf88083aac260c33',
#         'width': 64}],
#       'name': 'Hopes and Fears (Deluxe Edition)',
#       'release_date': '2009-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 37,
#       'type': 'album',
#       'uri': 'spotify:album:5QqVXRTiGpLgmo1YNoz9Bk'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#        'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#        'id': '53A0W3U0s8diEn9RhXQhVz',
#        'name': 'Keane',
#        'type': 'artist',
#        'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 345933,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAN0400091'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5b7wNSn8yuj5ZZ3JAlzoBt'},
#      'href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#      'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#      'is_local': False,
#      'name': 'She Has No Time',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:20Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#         'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#         'id': '50JJSqHUf2RQ9xsHs0KMHg',
#         'name': 'Jon Bellion',
#         'type': 'artist',
#         'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2e8nzTZ0HtK94IifOWgN7o'},
#       'href': 'https://api.spotify.com/v1/albums/2e8nzTZ0HtK94IifOWgN7o',
#       'id': '2e8nzTZ0HtK94IifOWgN7o',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a01c1fddc334c0bd15e4452d',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a01c1fddc334c0bd15e4452d',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a01c1fddc334c0bd15e4452d',
#         'width': 64}],
#       'name': 'The Human Condition',
#       'release_date': '2016-06-10',
#       'release_date_precision': 'day',
#       'total_tracks': 14,
#       'type': 'album',
#       'uri': 'spotify:album:2e8nzTZ0HtK94IifOWgN7o'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#        'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#        'id': '50JJSqHUf2RQ9xsHs0KMHg',
#        'name': 'Jon Bellion',
#        'type': 'artist',
#        'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 217603,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUM71603666'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1CnPYaKxTVb4LWOtiGOm0m'},
#      'href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#      'id': '1CnPYaKxTVb4LWOtiGOm0m',
#      'is_local': False,
#      'name': 'All Time Low',
#      'popularity': 69,
#      'preview_url': None,
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:23Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#         'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#         'id': '0sYlth2PW1zWJMEU2vCukz',
#         'name': 'Flower Face',
#         'type': 'artist',
#         'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7x2x5b3TNBaiQqlKUwlNVM'},
#       'href': 'https://api.spotify.com/v1/albums/7x2x5b3TNBaiQqlKUwlNVM',
#       'id': '7x2x5b3TNBaiQqlKUwlNVM',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736293eae65ffd59901275b003',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026293eae65ffd59901275b003',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516293eae65ffd59901275b003',
#         'width': 64}],
#       'name': 'Baby Teeth',
#       'release_date': '2018-03-10',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:7x2x5b3TNBaiQqlKUwlNVM'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#        'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#        'id': '0sYlth2PW1zWJMEU2vCukz',
#        'name': 'Flower Face',
#        'type': 'artist',
#        'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 281843,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMAAK1807702'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1M8OAc4NnD5GFMUiqjebaS'},
#      'href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#      'id': '1M8OAc4NnD5GFMUiqjebaS',
#      'is_local': False,
#      'name': 'Baby Teeth',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/8865a35ec0a2572bbbd005d7049ed327c64d4fa6?cid=d062190fd93b4e4488e75ae2d9256814',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:27Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#         'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#         'id': '3kZdsaTYgaaolNxpnJ4iDe',
#         'name': 'Son Lux',
#         'type': 'artist',
#         'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6dJKjotJRGEE9rmGgmxDWu'},
#       'href': 'https://api.spotify.com/v1/albums/6dJKjotJRGEE9rmGgmxDWu',
#       'id': '6dJKjotJRGEE9rmGgmxDWu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27363e74fdfbcd4f37a18ab1596',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0263e74fdfbcd4f37a18ab1596',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485163e74fdfbcd4f37a18ab1596',
#         'width': 64}],
#       'name': 'Everything Everywhere All at Once (Original Motion Picture Soundtrack)',
#       'release_date': '2022-04-08',
#       'release_date_precision': 'day',
#       'total_tracks': 49,
#       'type': 'album',
#       'uri': 'spotify:album:6dJKjotJRGEE9rmGgmxDWu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#        'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#        'id': '3kZdsaTYgaaolNxpnJ4iDe',
#        'name': 'Son Lux',
#        'type': 'artist',
#        'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#        'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#        'id': '2uYWxilOVlUdk4oV9DvwqK',
#        'name': 'Mitski',
#        'type': 'artist',
#        'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/20vuBdFblWUo2FCOvUzusB'},
#        'href': 'https://api.spotify.com/v1/artists/20vuBdFblWUo2FCOvUzusB',
#        'id': '20vuBdFblWUo2FCOvUzusB',
#        'name': 'David Byrne',
#        'type': 'artist',
#        'uri': 'spotify:artist:20vuBdFblWUo2FCOvUzusB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 161022,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'QMB622200545'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/20UK2eUwlRzNuW60gzITuj'},
#      'href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#      'id': '20UK2eUwlRzNuW60gzITuj',
#      'is_local': False,
#      'name': 'This Is A Life',
#      'popularity': 55,
#      'preview_url': 'https://p.scdn.co/mp3-preview/1e99529b9b43ffb0121222ad16451e8db8cdf551?cid=d062190fd93b4e4488e75ae2d9256814',
#      'track': True,
#      'track_number': 45,
#      'type': 'track',
#      'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:29Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#         'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#         'id': '3ICflSq6ZgYAIrm2CTkfVP',
#         'name': 'The Animals',
#         'type': 'artist',
#         'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1v4O55JGou3T0Vlj06fdXz'},
#       'href': 'https://api.spotify.com/v1/albums/1v4O55JGou3T0Vlj06fdXz',
#       'id': '1v4O55JGou3T0Vlj06fdXz',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273015c484a7aca592df1a77828',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02015c484a7aca592df1a77828',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851015c484a7aca592df1a77828',
#         'width': 64}],
#       'name': 'The Singles Plus',
#       'release_date': '1987-10-19',
#       'release_date_precision': 'day',
#       'total_tracks': 20,
#       'type': 'album',
#       'uri': 'spotify:album:1v4O55JGou3T0Vlj06fdXz'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#        'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#        'id': '3ICflSq6ZgYAIrm2CTkfVP',
#        'name': 'The Animals',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269906,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAYE6400209'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4mn2kNTqiGLwaUR8JdhJ1l'},
#      'href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#      'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#      'is_local': False,
#      'name': 'House of the Rising Sun',
#      'popularity': 74,
#      'preview_url': None,
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:32Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#         'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#         'id': '4Z8W4fKeB5YxbusRsdQVPb',
#         'name': 'Radiohead',
#         'type': 'artist',
#         'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#       'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#       'id': '6400dnyeDyD2mIFHfkwHXN',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512f85b65d3ac4d3d7f806ca11',
#         'width': 64}],
#       'name': 'Pablo Honey',
#       'release_date': '1993-02-22',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:6400dnyeDyD2mIFHfkwHXN'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 238640,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'GBAYE9200070'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6b2oQwSGFkzsMtQruIWm2p'},
#      'href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#      'id': '6b2oQwSGFkzsMtQruIWm2p',
#      'is_local': False,
#      'name': 'Creep',
#      'popularity': 2,
#      'preview_url': None,
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:42Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#         'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#         'id': '1kDGbuxWknIKx4FlgWxiSp',
#         'name': 'Nothing But Thieves',
#         'type': 'artist',
#         'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0vBxqUHwetFn5jCwAKX7Uk'},
#       'href': 'https://api.spotify.com/v1/albums/0vBxqUHwetFn5jCwAKX7Uk',
#       'id': '0vBxqUHwetFn5jCwAKX7Uk',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273176e29e598499208ff338ae1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02176e29e598499208ff338ae1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851176e29e598499208ff338ae1',
#         'width': 64}],
#       'name': 'Nothing But Thieves (Track by Track)',
#       'release_date': '2015-10-09',
#       'release_date_precision': 'day',
#       'total_tracks': 32,
#       'type': 'album',
#       'uri': 'spotify:album:0vBxqUHwetFn5jCwAKX7Uk'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#        'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#        'id': '1kDGbuxWknIKx4FlgWxiSp',
#        'name': 'Nothing But Thieves',
#        'type': 'artist',
#        'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 227013,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBARL1500803'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2yoxjQT7P2D1dhvxJGWWi8'},
#      'href': 'https://api.spotify.com/v1/tracks/2yoxjQT7P2D1dhvxJGWWi8',
#      'id': '2yoxjQT7P2D1dhvxJGWWi8',
#      'is_local': False,
#      'name': 'Six Billion',
#      'popularity': 39,
#      'preview_url': 'https://p.scdn.co/mp3-preview/ac29e03dd6e69cf75429ccd3f8fe65ce43794770?cid=d062190fd93b4e4488e75ae2d9256814',
#      'track': True,
#      'track_number': 32,
#      'type': 'track',
#      'uri': 'spotify:track:2yoxjQT7P2D1dhvxJGWWi8'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-12-05T19:39:46Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#      'href': 'https://api.spotify.com/v1/users/bullseye012',
#      'id': 'bullseye012',
#      'type': 'user',
#      'uri': 'spotify:user:bullseye012'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#         'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#         'id': '7n2wHs1TKAczGzO7Dd2rGr',
#         'name': 'Shawn Mendes',
#         'type': 'artist',
#         'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1ne2D0NxoGyZd31gAM4HNd'},
#       'href': 'https://api.spotify.com/v1/albums/1ne2D0NxoGyZd31gAM4HNd',
#       'id': '1ne2D0NxoGyZd31gAM4HNd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731376b4b16f4bfcba02dc571b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021376b4b16f4bfcba02dc571b',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511376b4b16f4bfcba02dc571b',
#         'width': 64}],
#       'name': 'Illuminate',
#       'release_date': '2017-04-20',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:1ne2D0NxoGyZd31gAM4HNd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#        'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#        'id': '7n2wHs1TKAczGzO7Dd2rGr',
#        'name': 'Shawn Mendes',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 187973,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUM71604711'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3QGsuHI8jO1Rx4JWLUh9jd'},
#      'href': 'https://api.spotify.com/v1/tracks/3QGsuHI8jO1Rx4JWLUh9jd',
#      'id': '3QGsuHI8jO1Rx4JWLUh9jd',
#      'is_local': False,
#      'name': 'Treat You Better',
#      'popularity': 84,
#      'preview_url': None,
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 9},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:4HC1kIY2bof1CHfZqmo8u1'}

# %%
liked_songs = playlist_l["tracks"]["items"] 
liked_songs
# Out:
# [{'added_at': '2022-12-05T18:12:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#       'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#       'id': '19eLuQmk9aCobbVDHc6eek',
#       'name': 'Louis Armstrong',
#       'type': 'artist',
#       'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6mmv0gwumlFGWDGJXF4yEv'},
#     'href': 'https://api.spotify.com/v1/albums/6mmv0gwumlFGWDGJXF4yEv',
#     'id': '6mmv0gwumlFGWDGJXF4yEv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273845a5660b804e5f3e821fbed',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02845a5660b804e5f3e821fbed',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851845a5660b804e5f3e821fbed',
#       'width': 64}],
#     'name': 'What A Wonderful World',
#     'release_date': '1968-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6mmv0gwumlFGWDGJXF4yEv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#      'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#      'id': '19eLuQmk9aCobbVDHc6eek',
#      'name': 'Louis Armstrong',
#      'type': 'artist',
#      'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 139226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC16758823'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/29U7stRjqHU6rMiS8BfaI9'},
#    'href': 'https://api.spotify.com/v1/tracks/29U7stRjqHU6rMiS8BfaI9',
#    'id': '29U7stRjqHU6rMiS8BfaI9',
#    'is_local': False,
#    'name': 'What A Wonderful World',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:29U7stRjqHU6rMiS8BfaI9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:12:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/75nZGvjStgCUavXcsYsXf7'},
#     'href': 'https://api.spotify.com/v1/albums/75nZGvjStgCUavXcsYsXf7',
#     'id': '75nZGvjStgCUavXcsYsXf7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c5eb6ea693bf928ca3e13661',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c5eb6ea693bf928ca3e13661',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c5eb6ea693bf928ca3e13661',
#       'width': 64}],
#     'name': 'The Shark in Your Water',
#     'release_date': '2022-05-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:75nZGvjStgCUavXcsYsXf7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 188864,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAN112100630'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2MfwT3SKUyF0na2LCa2fCp'},
#    'href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#    'id': '2MfwT3SKUyF0na2LCa2fCp',
#    'is_local': False,
#    'name': 'Cornflower Blue',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0ed6d70223d702345bc06dd471fea0674c867298?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:12:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#       'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#       'id': '53A0W3U0s8diEn9RhXQhVz',
#       'name': 'Keane',
#       'type': 'artist',
#       'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5QqVXRTiGpLgmo1YNoz9Bk'},
#     'href': 'https://api.spotify.com/v1/albums/5QqVXRTiGpLgmo1YNoz9Bk',
#     'id': '5QqVXRTiGpLgmo1YNoz9Bk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1a0d9a7cf88083aac260c33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1a0d9a7cf88083aac260c33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1a0d9a7cf88083aac260c33',
#       'width': 64}],
#     'name': 'Hopes and Fears (Deluxe Edition)',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:5QqVXRTiGpLgmo1YNoz9Bk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#      'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#      'id': '53A0W3U0s8diEn9RhXQhVz',
#      'name': 'Keane',
#      'type': 'artist',
#      'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 345933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAN0400091'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5b7wNSn8yuj5ZZ3JAlzoBt'},
#    'href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#    'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#    'is_local': False,
#    'name': 'She Has No Time',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#       'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#       'id': '50JJSqHUf2RQ9xsHs0KMHg',
#       'name': 'Jon Bellion',
#       'type': 'artist',
#       'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2e8nzTZ0HtK94IifOWgN7o'},
#     'href': 'https://api.spotify.com/v1/albums/2e8nzTZ0HtK94IifOWgN7o',
#     'id': '2e8nzTZ0HtK94IifOWgN7o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a01c1fddc334c0bd15e4452d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a01c1fddc334c0bd15e4452d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a01c1fddc334c0bd15e4452d',
#       'width': 64}],
#     'name': 'The Human Condition',
#     'release_date': '2016-06-10',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2e8nzTZ0HtK94IifOWgN7o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#      'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#      'id': '50JJSqHUf2RQ9xsHs0KMHg',
#      'name': 'Jon Bellion',
#      'type': 'artist',
#      'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 217603,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71603666'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1CnPYaKxTVb4LWOtiGOm0m'},
#    'href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#    'id': '1CnPYaKxTVb4LWOtiGOm0m',
#    'is_local': False,
#    'name': 'All Time Low',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7x2x5b3TNBaiQqlKUwlNVM'},
#     'href': 'https://api.spotify.com/v1/albums/7x2x5b3TNBaiQqlKUwlNVM',
#     'id': '7x2x5b3TNBaiQqlKUwlNVM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736293eae65ffd59901275b003',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026293eae65ffd59901275b003',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516293eae65ffd59901275b003',
#       'width': 64}],
#     'name': 'Baby Teeth',
#     'release_date': '2018-03-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7x2x5b3TNBaiQqlKUwlNVM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 281843,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMAAK1807702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1M8OAc4NnD5GFMUiqjebaS'},
#    'href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#    'id': '1M8OAc4NnD5GFMUiqjebaS',
#    'is_local': False,
#    'name': 'Baby Teeth',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8865a35ec0a2572bbbd005d7049ed327c64d4fa6?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#       'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#       'id': '3kZdsaTYgaaolNxpnJ4iDe',
#       'name': 'Son Lux',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6dJKjotJRGEE9rmGgmxDWu'},
#     'href': 'https://api.spotify.com/v1/albums/6dJKjotJRGEE9rmGgmxDWu',
#     'id': '6dJKjotJRGEE9rmGgmxDWu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27363e74fdfbcd4f37a18ab1596',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0263e74fdfbcd4f37a18ab1596',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485163e74fdfbcd4f37a18ab1596',
#       'width': 64}],
#     'name': 'Everything Everywhere All at Once (Original Motion Picture Soundtrack)',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 49,
#     'type': 'album',
#     'uri': 'spotify:album:6dJKjotJRGEE9rmGgmxDWu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#      'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#      'id': '3kZdsaTYgaaolNxpnJ4iDe',
#      'name': 'Son Lux',
#      'type': 'artist',
#      'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/20vuBdFblWUo2FCOvUzusB'},
#      'href': 'https://api.spotify.com/v1/artists/20vuBdFblWUo2FCOvUzusB',
#      'id': '20vuBdFblWUo2FCOvUzusB',
#      'name': 'David Byrne',
#      'type': 'artist',
#      'uri': 'spotify:artist:20vuBdFblWUo2FCOvUzusB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 161022,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMB622200545'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/20UK2eUwlRzNuW60gzITuj'},
#    'href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#    'id': '20UK2eUwlRzNuW60gzITuj',
#    'is_local': False,
#    'name': 'This Is A Life',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1e99529b9b43ffb0121222ad16451e8db8cdf551?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 45,
#    'type': 'track',
#    'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#       'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#       'id': '3ICflSq6ZgYAIrm2CTkfVP',
#       'name': 'The Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1v4O55JGou3T0Vlj06fdXz'},
#     'href': 'https://api.spotify.com/v1/albums/1v4O55JGou3T0Vlj06fdXz',
#     'id': '1v4O55JGou3T0Vlj06fdXz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273015c484a7aca592df1a77828',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02015c484a7aca592df1a77828',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851015c484a7aca592df1a77828',
#       'width': 64}],
#     'name': 'The Singles Plus',
#     'release_date': '1987-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:1v4O55JGou3T0Vlj06fdXz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#      'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#      'id': '3ICflSq6ZgYAIrm2CTkfVP',
#      'name': 'The Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 269906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE6400209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4mn2kNTqiGLwaUR8JdhJ1l'},
#    'href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#    'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#    'is_local': False,
#    'name': 'House of the Rising Sun',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#     'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#     'id': '6400dnyeDyD2mIFHfkwHXN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512f85b65d3ac4d3d7f806ca11',
#       'width': 64}],
#     'name': 'Pablo Honey',
#     'release_date': '1993-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6400dnyeDyD2mIFHfkwHXN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 238640,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAYE9200070'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6b2oQwSGFkzsMtQruIWm2p'},
#    'href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#    'id': '6b2oQwSGFkzsMtQruIWm2p',
#    'is_local': False,
#    'name': 'Creep',
#    'popularity': 2,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T18:13:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#       'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#       'id': '1kDGbuxWknIKx4FlgWxiSp',
#       'name': 'Nothing But Thieves',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0vBxqUHwetFn5jCwAKX7Uk'},
#     'href': 'https://api.spotify.com/v1/albums/0vBxqUHwetFn5jCwAKX7Uk',
#     'id': '0vBxqUHwetFn5jCwAKX7Uk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273176e29e598499208ff338ae1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02176e29e598499208ff338ae1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851176e29e598499208ff338ae1',
#       'width': 64}],
#     'name': 'Nothing But Thieves (Track by Track)',
#     'release_date': '2015-10-09',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:0vBxqUHwetFn5jCwAKX7Uk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#      'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#      'id': '1kDGbuxWknIKx4FlgWxiSp',
#      'name': 'Nothing But Thieves',
#      'type': 'artist',
#      'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
# ...
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731551c93dfa33ea4f30ef4eea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511551c93dfa33ea4f30ef4eea',
#       'width': 64}],
#     'name': 'Smoke + Mirrors (Deluxe)',
#     'release_date': '2015-10-30',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:6ecx4OFG0nlUMqAi9OXQER'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#      'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#      'id': '53XhwfbYqKCa1cC15pYq2q',
#      'name': 'Imagine Dragons',
#      'type': 'artist',
#      'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LC',
#     'LI',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 217973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71417943'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6FQcdl2PzmsoXRF3F1flZ5'},
#    'href': 'https://api.spotify.com/v1/tracks/6FQcdl2PzmsoXRF3F1flZ5',
#    'id': '6FQcdl2PzmsoXRF3F1flZ5',
#    'is_local': False,
#    'name': 'Second Chances',
#    'popularity': 44,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:6FQcdl2PzmsoXRF3F1flZ5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:05:20Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5T7a0lQ6x5ABq8LtJGyTm2'},
#       'href': 'https://api.spotify.com/v1/artists/5T7a0lQ6x5ABq8LtJGyTm2',
#       'id': '5T7a0lQ6x5ABq8LtJGyTm2',
#       'name': 'Rope Sect',
#       'type': 'artist',
#       'uri': 'spotify:artist:5T7a0lQ6x5ABq8LtJGyTm2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/06MHIEC2w0OA7QrqHDW67W'},
#     'href': 'https://api.spotify.com/v1/albums/06MHIEC2w0OA7QrqHDW67W',
#     'id': '06MHIEC2w0OA7QrqHDW67W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273310226321de080f13774bbf3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02310226321de080f13774bbf3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851310226321de080f13774bbf3',
#       'width': 64}],
#     'name': 'Handsome Youth',
#     'release_date': '2019-03-18',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:06MHIEC2w0OA7QrqHDW67W'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5T7a0lQ6x5ABq8LtJGyTm2'},
#      'href': 'https://api.spotify.com/v1/artists/5T7a0lQ6x5ABq8LtJGyTm2',
#      'id': '5T7a0lQ6x5ABq8LtJGyTm2',
#      'name': 'Rope Sect',
#      'type': 'artist',
#      'uri': 'spotify:artist:5T7a0lQ6x5ABq8LtJGyTm2'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 226890,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DELJ81914286'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5kkqN6Lx3ZioloqqxC7Kyj'},
#    'href': 'https://api.spotify.com/v1/tracks/5kkqN6Lx3ZioloqqxC7Kyj',
#    'id': '5kkqN6Lx3ZioloqqxC7Kyj',
#    'is_local': False,
#    'name': 'Handsome Youth',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7c2999846962dddd8540c3ff72d8fefc6ed42aed?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5kkqN6Lx3ZioloqqxC7Kyj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:05:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ocgnj3keqnoeyri37ycogxapy'},
#    'href': 'https://api.spotify.com/v1/users/ocgnj3keqnoeyri37ycogxapy',
#    'id': 'ocgnj3keqnoeyri37ycogxapy',
#    'type': 'user',
#    'uri': 'spotify:user:ocgnj3keqnoeyri37ycogxapy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vkqYmiPBYLaalcmjujWxK'},
#     'href': 'https://api.spotify.com/v1/albums/5vkqYmiPBYLaalcmjujWxK',
#     'id': '5vkqYmiPBYLaalcmjujWxK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de3c04b5fc750b68899b20a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de3c04b5fc750b68899b20a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de3c04b5fc750b68899b20a9',
#       'width': 64}],
#     'name': 'In Rainbows',
#     'release_date': '2007-12-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5vkqYmiPBYLaalcmjujWxK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 228746,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBSTK0700005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Qv2Nby1xTr9pQyjkrc94J'},
#    'href': 'https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9pQyjkrc94J',
#    'id': '5Qv2Nby1xTr9pQyjkrc94J',
#    'is_local': False,
#    'name': 'All I Need',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f3ea52a5c549e46e86495e2329cf79d2c03c0a27?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5Qv2Nby1xTr9pQyjkrc94J'},
#   'video_thumbnail': {'url': None}}]

# %%
liked_ids = [] 
for i in range(len(liked_songs)): 
    liked_ids.append(liked_songs[i]["track"]["id"])

# %%
liked_features = sp.audio_features(liked_ids)

# %%
liked_df = pd.DataFrame(liked_features)
liked_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.271   0.165    5   -20.652     1       0.0351        0.7290
# 1          0.177   0.215    3    -9.886     1       0.0335        0.8070
# 2          0.530   0.497    0   -11.348     1       0.0322        0.4980
# 3          0.617   0.567    0    -4.188     1       0.0828        0.0584
# 4          0.214   0.367    6   -10.858     0       0.0321        0.8440
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.374   0.249    1   -10.985     1       0.0395        0.9360
# 96         0.588   0.362    8   -13.062     1       0.0295        0.4330
# 97         0.401   0.567   10    -9.131     1       0.0355        0.1710
# 98         0.626   0.308    6   -17.163     0       0.0294        0.8300
# 99         0.670   0.478    4    -8.689     0       0.0355        0.5310
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.1180   0.2030   77.082  audio_features
# 1           0.000125    0.0921   0.0415   75.862  audio_features
# 2           0.000384    0.0665   0.1000  141.977  audio_features
# 3           0.000000    0.0933   0.5050   90.246  audio_features
# 4           0.018100    0.1880   0.1750   79.854  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.008760    0.1140   0.0633  128.018  audio_features
# 96          0.004680    0.0904   0.0995  132.472  audio_features
# 97          0.008590    0.1030   0.3620  171.059  audio_features
# 98          0.057800    0.1080   0.3230  129.928  audio_features
# 99          0.428000    0.1380   0.0997   88.014  audio_features
#
#                         id                                   uri  \
# 0   29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1   2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2   5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3   1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4   1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                     ...                                   ...
# 95  4eCXQY1vh9XMW66LmS5alP  spotify:track:4eCXQY1vh9XMW66LmS5alP
# 96  6UzdCUyZa27ez12pK56uSo  spotify:track:6UzdCUyZa27ez12pK56uSo
# 97  6FQcdl2PzmsoXRF3F1flZ5  spotify:track:6FQcdl2PzmsoXRF3F1flZ5
# 98  5kkqN6Lx3ZioloqqxC7Kyj  spotify:track:5kkqN6Lx3ZioloqqxC7Kyj
# 99  5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1   https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2   https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3   https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4   https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4eCXQY1vh9XM...
# 96  https://api.spotify.com/v1/tracks/6UzdCUyZa27e...
# 97  https://api.spotify.com/v1/tracks/6FQcdl2Pzmso...
# 98  https://api.spotify.com/v1/tracks/5kkqN6Lx3Zio...
# 99  https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/29U7...       139227
# 1   https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 2   https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 3   https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 4   https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4eCX...       200093
# 96  https://api.spotify.com/v1/audio-analysis/6Uzd...       379653
# 97  https://api.spotify.com/v1/audio-analysis/6FQc...       217973
# 98  https://api.spotify.com/v1/audio-analysis/5kkq...       226890
# 99  https://api.spotify.com/v1/audio-analysis/5Qv2...       228747
#
#     time_signature
# 0                4
# 1                3
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               3
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
target = []

for i in range(liked_df.shape[0]):
    target.append(1)

# %%
liked_df['target'] = target
liked_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.271   0.165    5   -20.652     1       0.0351        0.7290
# 1          0.177   0.215    3    -9.886     1       0.0335        0.8070
# 2          0.530   0.497    0   -11.348     1       0.0322        0.4980
# 3          0.617   0.567    0    -4.188     1       0.0828        0.0584
# 4          0.214   0.367    6   -10.858     0       0.0321        0.8440
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.374   0.249    1   -10.985     1       0.0395        0.9360
# 96         0.588   0.362    8   -13.062     1       0.0295        0.4330
# 97         0.401   0.567   10    -9.131     1       0.0355        0.1710
# 98         0.626   0.308    6   -17.163     0       0.0294        0.8300
# 99         0.670   0.478    4    -8.689     0       0.0355        0.5310
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000002    0.1180   0.2030   77.082  audio_features
# 1           0.000125    0.0921   0.0415   75.862  audio_features
# 2           0.000384    0.0665   0.1000  141.977  audio_features
# 3           0.000000    0.0933   0.5050   90.246  audio_features
# 4           0.018100    0.1880   0.1750   79.854  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.008760    0.1140   0.0633  128.018  audio_features
# 96          0.004680    0.0904   0.0995  132.472  audio_features
# 97          0.008590    0.1030   0.3620  171.059  audio_features
# 98          0.057800    0.1080   0.3230  129.928  audio_features
# 99          0.428000    0.1380   0.0997   88.014  audio_features
#
#                         id                                   uri  \
# 0   29U7stRjqHU6rMiS8BfaI9  spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1   2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2   5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3   1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4   1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                     ...                                   ...
# 95  4eCXQY1vh9XMW66LmS5alP  spotify:track:4eCXQY1vh9XMW66LmS5alP
# 96  6UzdCUyZa27ez12pK56uSo  spotify:track:6UzdCUyZa27ez12pK56uSo
# 97  6FQcdl2PzmsoXRF3F1flZ5  spotify:track:6FQcdl2PzmsoXRF3F1flZ5
# 98  5kkqN6Lx3ZioloqqxC7Kyj  spotify:track:5kkqN6Lx3ZioloqqxC7Kyj
# 99  5Qv2Nby1xTr9pQyjkrc94J  spotify:track:5Qv2Nby1xTr9pQyjkrc94J
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1   https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2   https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3   https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4   https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4eCXQY1vh9XM...
# 96  https://api.spotify.com/v1/tracks/6UzdCUyZa27e...
# 97  https://api.spotify.com/v1/tracks/6FQcdl2Pzmso...
# 98  https://api.spotify.com/v1/tracks/5kkqN6Lx3Zio...
# 99  https://api.spotify.com/v1/tracks/5Qv2Nby1xTr9...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/29U7...       139227
# 1   https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 2   https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 3   https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 4   https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4eCX...       200093
# 96  https://api.spotify.com/v1/audio-analysis/6Uzd...       379653
# 97  https://api.spotify.com/v1/audio-analysis/6FQc...       217973
# 98  https://api.spotify.com/v1/audio-analysis/5kkq...       226890
# 99  https://api.spotify.com/v1/audio-analysis/5Qv2...       228747
#
#     time_signature  target
# 0                4       1
# 1                3       1
# 2                4       1
# 3                4       1
# 4                4       1
# ..             ...     ...
# 95               4       1
# 96               4       1
# 97               3       1
# 98               4       1
# 99               4       1
#
# [100 rows x 19 columns]

# %%
disliked_songs = playlist_d["tracks"]["items"] 
disliked_songs
# Out:
# [{'added_at': '2022-12-05T19:39:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/75nZGvjStgCUavXcsYsXf7'},
#     'href': 'https://api.spotify.com/v1/albums/75nZGvjStgCUavXcsYsXf7',
#     'id': '75nZGvjStgCUavXcsYsXf7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c5eb6ea693bf928ca3e13661',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c5eb6ea693bf928ca3e13661',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c5eb6ea693bf928ca3e13661',
#       'width': 64}],
#     'name': 'The Shark in Your Water',
#     'release_date': '2022-05-27',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:75nZGvjStgCUavXcsYsXf7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 188864,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAN112100630'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2MfwT3SKUyF0na2LCa2fCp'},
#    'href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#    'id': '2MfwT3SKUyF0na2LCa2fCp',
#    'is_local': False,
#    'name': 'Cornflower Blue',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0ed6d70223d702345bc06dd471fea0674c867298?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#       'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#       'id': '53A0W3U0s8diEn9RhXQhVz',
#       'name': 'Keane',
#       'type': 'artist',
#       'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5QqVXRTiGpLgmo1YNoz9Bk'},
#     'href': 'https://api.spotify.com/v1/albums/5QqVXRTiGpLgmo1YNoz9Bk',
#     'id': '5QqVXRTiGpLgmo1YNoz9Bk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d1a0d9a7cf88083aac260c33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d1a0d9a7cf88083aac260c33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d1a0d9a7cf88083aac260c33',
#       'width': 64}],
#     'name': 'Hopes and Fears (Deluxe Edition)',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:5QqVXRTiGpLgmo1YNoz9Bk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53A0W3U0s8diEn9RhXQhVz'},
#      'href': 'https://api.spotify.com/v1/artists/53A0W3U0s8diEn9RhXQhVz',
#      'id': '53A0W3U0s8diEn9RhXQhVz',
#      'name': 'Keane',
#      'type': 'artist',
#      'uri': 'spotify:artist:53A0W3U0s8diEn9RhXQhVz'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 345933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAN0400091'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5b7wNSn8yuj5ZZ3JAlzoBt'},
#    'href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#    'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#    'is_local': False,
#    'name': 'She Has No Time',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:20Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#       'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#       'id': '50JJSqHUf2RQ9xsHs0KMHg',
#       'name': 'Jon Bellion',
#       'type': 'artist',
#       'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2e8nzTZ0HtK94IifOWgN7o'},
#     'href': 'https://api.spotify.com/v1/albums/2e8nzTZ0HtK94IifOWgN7o',
#     'id': '2e8nzTZ0HtK94IifOWgN7o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a01c1fddc334c0bd15e4452d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a01c1fddc334c0bd15e4452d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a01c1fddc334c0bd15e4452d',
#       'width': 64}],
#     'name': 'The Human Condition',
#     'release_date': '2016-06-10',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2e8nzTZ0HtK94IifOWgN7o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'},
#      'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg',
#      'id': '50JJSqHUf2RQ9xsHs0KMHg',
#      'name': 'Jon Bellion',
#      'type': 'artist',
#      'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 217603,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM71603666'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1CnPYaKxTVb4LWOtiGOm0m'},
#    'href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#    'id': '1CnPYaKxTVb4LWOtiGOm0m',
#    'is_local': False,
#    'name': 'All Time Low',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#       'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#       'id': '0sYlth2PW1zWJMEU2vCukz',
#       'name': 'Flower Face',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7x2x5b3TNBaiQqlKUwlNVM'},
#     'href': 'https://api.spotify.com/v1/albums/7x2x5b3TNBaiQqlKUwlNVM',
#     'id': '7x2x5b3TNBaiQqlKUwlNVM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736293eae65ffd59901275b003',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026293eae65ffd59901275b003',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516293eae65ffd59901275b003',
#       'width': 64}],
#     'name': 'Baby Teeth',
#     'release_date': '2018-03-10',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7x2x5b3TNBaiQqlKUwlNVM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sYlth2PW1zWJMEU2vCukz'},
#      'href': 'https://api.spotify.com/v1/artists/0sYlth2PW1zWJMEU2vCukz',
#      'id': '0sYlth2PW1zWJMEU2vCukz',
#      'name': 'Flower Face',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sYlth2PW1zWJMEU2vCukz'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 281843,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMAAK1807702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1M8OAc4NnD5GFMUiqjebaS'},
#    'href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#    'id': '1M8OAc4NnD5GFMUiqjebaS',
#    'is_local': False,
#    'name': 'Baby Teeth',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8865a35ec0a2572bbbd005d7049ed327c64d4fa6?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#       'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#       'id': '3kZdsaTYgaaolNxpnJ4iDe',
#       'name': 'Son Lux',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6dJKjotJRGEE9rmGgmxDWu'},
#     'href': 'https://api.spotify.com/v1/albums/6dJKjotJRGEE9rmGgmxDWu',
#     'id': '6dJKjotJRGEE9rmGgmxDWu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27363e74fdfbcd4f37a18ab1596',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0263e74fdfbcd4f37a18ab1596',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485163e74fdfbcd4f37a18ab1596',
#       'width': 64}],
#     'name': 'Everything Everywhere All at Once (Original Motion Picture Soundtrack)',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 49,
#     'type': 'album',
#     'uri': 'spotify:album:6dJKjotJRGEE9rmGgmxDWu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kZdsaTYgaaolNxpnJ4iDe'},
#      'href': 'https://api.spotify.com/v1/artists/3kZdsaTYgaaolNxpnJ4iDe',
#      'id': '3kZdsaTYgaaolNxpnJ4iDe',
#      'name': 'Son Lux',
#      'type': 'artist',
#      'uri': 'spotify:artist:3kZdsaTYgaaolNxpnJ4iDe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/20vuBdFblWUo2FCOvUzusB'},
#      'href': 'https://api.spotify.com/v1/artists/20vuBdFblWUo2FCOvUzusB',
#      'id': '20vuBdFblWUo2FCOvUzusB',
#      'name': 'David Byrne',
#      'type': 'artist',
#      'uri': 'spotify:artist:20vuBdFblWUo2FCOvUzusB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 161022,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMB622200545'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/20UK2eUwlRzNuW60gzITuj'},
#    'href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#    'id': '20UK2eUwlRzNuW60gzITuj',
#    'is_local': False,
#    'name': 'This Is A Life',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1e99529b9b43ffb0121222ad16451e8db8cdf551?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 45,
#    'type': 'track',
#    'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#       'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#       'id': '3ICflSq6ZgYAIrm2CTkfVP',
#       'name': 'The Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1v4O55JGou3T0Vlj06fdXz'},
#     'href': 'https://api.spotify.com/v1/albums/1v4O55JGou3T0Vlj06fdXz',
#     'id': '1v4O55JGou3T0Vlj06fdXz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273015c484a7aca592df1a77828',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02015c484a7aca592df1a77828',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851015c484a7aca592df1a77828',
#       'width': 64}],
#     'name': 'The Singles Plus',
#     'release_date': '1987-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:1v4O55JGou3T0Vlj06fdXz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ICflSq6ZgYAIrm2CTkfVP'},
#      'href': 'https://api.spotify.com/v1/artists/3ICflSq6ZgYAIrm2CTkfVP',
#      'id': '3ICflSq6ZgYAIrm2CTkfVP',
#      'name': 'The Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ICflSq6ZgYAIrm2CTkfVP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 269906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE6400209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4mn2kNTqiGLwaUR8JdhJ1l'},
#    'href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#    'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#    'is_local': False,
#    'name': 'House of the Rising Sun',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#     'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#     'id': '6400dnyeDyD2mIFHfkwHXN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512f85b65d3ac4d3d7f806ca11',
#       'width': 64}],
#     'name': 'Pablo Honey',
#     'release_date': '1993-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6400dnyeDyD2mIFHfkwHXN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 238640,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBAYE9200070'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6b2oQwSGFkzsMtQruIWm2p'},
#    'href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#    'id': '6b2oQwSGFkzsMtQruIWm2p',
#    'is_local': False,
#    'name': 'Creep',
#    'popularity': 2,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#       'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#       'id': '1kDGbuxWknIKx4FlgWxiSp',
#       'name': 'Nothing But Thieves',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0vBxqUHwetFn5jCwAKX7Uk'},
#     'href': 'https://api.spotify.com/v1/albums/0vBxqUHwetFn5jCwAKX7Uk',
#     'id': '0vBxqUHwetFn5jCwAKX7Uk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273176e29e598499208ff338ae1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02176e29e598499208ff338ae1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851176e29e598499208ff338ae1',
#       'width': 64}],
#     'name': 'Nothing But Thieves (Track by Track)',
#     'release_date': '2015-10-09',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:0vBxqUHwetFn5jCwAKX7Uk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kDGbuxWknIKx4FlgWxiSp'},
#      'href': 'https://api.spotify.com/v1/artists/1kDGbuxWknIKx4FlgWxiSp',
#      'id': '1kDGbuxWknIKx4FlgWxiSp',
#      'name': 'Nothing But Thieves',
#      'type': 'artist',
#      'uri': 'spotify:artist:1kDGbuxWknIKx4FlgWxiSp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 227013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1500803'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2yoxjQT7P2D1dhvxJGWWi8'},
#    'href': 'https://api.spotify.com/v1/tracks/2yoxjQT7P2D1dhvxJGWWi8',
#    'id': '2yoxjQT7P2D1dhvxJGWWi8',
#    'is_local': False,
#    'name': 'Six Billion',
#    'popularity': 39,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ac29e03dd6e69cf75429ccd3f8fe65ce43794770?cid=d062190fd93b4e4488e75ae2d9256814',
#    'track': True,
#    'track_number': 32,
#    'type': 'track',
#    'uri': 'spotify:track:2yoxjQT7P2D1dhvxJGWWi8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-12-05T19:39:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bullseye012'},
#    'href': 'https://api.spotify.com/v1/users/bullseye012',
#    'id': 'bullseye012',
#    'type': 'user',
#    'uri': 'spotify:user:bullseye012'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ne2D0NxoGyZd31gAM4HNd'},
#     'href': 'https://api.spotify.com/v1/albums/1ne2D0NxoGyZd31gAM4HNd',
#     'id': '1ne2D0NxoGyZd31gAM4HNd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731376b4b16f4bfcba02dc571b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021376b4b16f4bfcba02dc571b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511376b4b16f4bfcba02dc571b',
#       'width': 64}],
#     'name': 'Illuminate',
#     'release_date': '2017-04-20',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1ne2D0NxoGyZd31gAM4HNd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#      'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#      'id': '7n2wHs1TKAczGzO7Dd2rGr',
#      'name': 'Shawn Mendes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 187973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71604711'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3QGsuHI8jO1Rx4JWLUh9jd'},
#    'href': 'https://api.spotify.com/v1/tracks/3QGsuHI8jO1Rx4JWLUh9jd',
#    'id': '3QGsuHI8jO1Rx4JWLUh9jd',
#    'is_local': False,
#    'name': 'Treat You Better',
#    'popularity': 84,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd'},
#   'video_thumbnail': {'url': None}}]

# %%
disliked_ids = []
for i in range(len(disliked_songs)): 
    disliked_ids.append(disliked_songs[i]["track"]["id"])

# %%
disliked_features = sp.audio_features(disliked_ids) 

disliked_features
# Out:
# [{'danceability': 0.177,
#   'energy': 0.215,
#   'key': 3,
#   'loudness': -9.886,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.807,
#   'instrumentalness': 0.000125,
#   'liveness': 0.0921,
#   'valence': 0.0415,
#   'tempo': 75.862,
#   'type': 'audio_features',
#   'id': '2MfwT3SKUyF0na2LCa2fCp',
#   'uri': 'spotify:track:2MfwT3SKUyF0na2LCa2fCp',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MfwT3SKUyF0na2LCa2fCp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MfwT3SKUyF0na2LCa2fCp',
#   'duration_ms': 188864,
#   'time_signature': 3},
#  {'danceability': 0.53,
#   'energy': 0.497,
#   'key': 0,
#   'loudness': -11.348,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.498,
#   'instrumentalness': 0.000384,
#   'liveness': 0.0665,
#   'valence': 0.1,
#   'tempo': 141.977,
#   'type': 'audio_features',
#   'id': '5b7wNSn8yuj5ZZ3JAlzoBt',
#   'uri': 'spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5b7wNSn8yuj5ZZ3JAlzoBt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5b7wNSn8yuj5ZZ3JAlzoBt',
#   'duration_ms': 345933,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -4.188,
#   'mode': 1,
#   'speechiness': 0.0828,
#   'acousticness': 0.0584,
#   'instrumentalness': 0,
#   'liveness': 0.0933,
#   'valence': 0.505,
#   'tempo': 90.246,
#   'type': 'audio_features',
#   'id': '1CnPYaKxTVb4LWOtiGOm0m',
#   'uri': 'spotify:track:1CnPYaKxTVb4LWOtiGOm0m',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CnPYaKxTVb4LWOtiGOm0m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CnPYaKxTVb4LWOtiGOm0m',
#   'duration_ms': 217603,
#   'time_signature': 4},
#  {'danceability': 0.214,
#   'energy': 0.367,
#   'key': 6,
#   'loudness': -10.858,
#   'mode': 0,
#   'speechiness': 0.0321,
#   'acousticness': 0.844,
#   'instrumentalness': 0.0181,
#   'liveness': 0.188,
#   'valence': 0.175,
#   'tempo': 79.854,
#   'type': 'audio_features',
#   'id': '1M8OAc4NnD5GFMUiqjebaS',
#   'uri': 'spotify:track:1M8OAc4NnD5GFMUiqjebaS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1M8OAc4NnD5GFMUiqjebaS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M8OAc4NnD5GFMUiqjebaS',
#   'duration_ms': 281844,
#   'time_signature': 4},
#  {'danceability': 0.236,
#   'energy': 0.156,
#   'key': 1,
#   'loudness': -16.973,
#   'mode': 0,
#   'speechiness': 0.0389,
#   'acousticness': 0.731,
#   'instrumentalness': 0,
#   'liveness': 0.127,
#   'valence': 0.0919,
#   'tempo': 85.78,
#   'type': 'audio_features',
#   'id': '20UK2eUwlRzNuW60gzITuj',
#   'uri': 'spotify:track:20UK2eUwlRzNuW60gzITuj',
#   'track_href': 'https://api.spotify.com/v1/tracks/20UK2eUwlRzNuW60gzITuj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20UK2eUwlRzNuW60gzITuj',
#   'duration_ms': 161022,
#   'time_signature': 4},
#  {'danceability': 0.316,
#   'energy': 0.484,
#   'key': 9,
#   'loudness': -9.11,
#   'mode': 0,
#   'speechiness': 0.0308,
#   'acousticness': 0.000334,
#   'instrumentalness': 0.00445,
#   'liveness': 0.0912,
#   'valence': 0.299,
#   'tempo': 117.363,
#   'type': 'audio_features',
#   'id': '4mn2kNTqiGLwaUR8JdhJ1l',
#   'uri': 'spotify:track:4mn2kNTqiGLwaUR8JdhJ1l',
#   'track_href': 'https://api.spotify.com/v1/tracks/4mn2kNTqiGLwaUR8JdhJ1l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4mn2kNTqiGLwaUR8JdhJ1l',
#   'duration_ms': 269907,
#   'time_signature': 3},
#  {'danceability': 0.515,
#   'energy': 0.43,
#   'key': 7,
#   'loudness': -9.935,
#   'mode': 1,
#   'speechiness': 0.0369,
#   'acousticness': 0.0102,
#   'instrumentalness': 0.000141,
#   'liveness': 0.129,
#   'valence': 0.104,
#   'tempo': 91.841,
#   'type': 'audio_features',
#   'id': '6b2oQwSGFkzsMtQruIWm2p',
#   'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p',
#   'track_href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2oQwSGFkzsMtQruIWm2p',
#   'duration_ms': 238640,
#   'time_signature': 4},
#  {'danceability': 0.443,
#   'energy': 0.461,
#   'key': 0,
#   'loudness': -6.224,
#   'mode': 0,
#   'speechiness': 0.0257,
#   'acousticness': 0.143,
#   'instrumentalness': 0.00956,
#   'liveness': 0.0952,
#   'valence': 0.182,
#   'tempo': 71.989,
#   'type': 'audio_features',
#   'id': '2yoxjQT7P2D1dhvxJGWWi8',
#   'uri': 'spotify:track:2yoxjQT7P2D1dhvxJGWWi8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2yoxjQT7P2D1dhvxJGWWi8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2yoxjQT7P2D1dhvxJGWWi8',
#   'duration_ms': 227013,
#   'time_signature': 4},
#  {'danceability': 0.444,
#   'energy': 0.819,
#   'key': 10,
#   'loudness': -4.078,
#   'mode': 0,
#   'speechiness': 0.341,
#   'acousticness': 0.106,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.747,
#   'tempo': 82.695,
#   'type': 'audio_features',
#   'id': '3QGsuHI8jO1Rx4JWLUh9jd',
#   'uri': 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QGsuHI8jO1Rx4JWLUh9jd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QGsuHI8jO1Rx4JWLUh9jd',
#   'duration_ms': 187973,
#   'time_signature': 4}]

# %%
disliked_df = pd.DataFrame(disliked_features)
disliked_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.177   0.215    3    -9.886     1       0.0335      0.807000
# 1         0.530   0.497    0   -11.348     1       0.0322      0.498000
# 2         0.617   0.567    0    -4.188     1       0.0828      0.058400
# 3         0.214   0.367    6   -10.858     0       0.0321      0.844000
# 4         0.236   0.156    1   -16.973     0       0.0389      0.731000
# 5         0.316   0.484    9    -9.110     0       0.0308      0.000334
# 6         0.515   0.430    7    -9.935     1       0.0369      0.010200
# 7         0.443   0.461    0    -6.224     0       0.0257      0.143000
# 8         0.444   0.819   10    -4.078     0       0.3410      0.106000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000125    0.0921   0.0415   75.862  audio_features
# 1          0.000384    0.0665   0.1000  141.977  audio_features
# 2          0.000000    0.0933   0.5050   90.246  audio_features
# 3          0.018100    0.1880   0.1750   79.854  audio_features
# 4          0.000000    0.1270   0.0919   85.780  audio_features
# 5          0.004450    0.0912   0.2990  117.363  audio_features
# 6          0.000141    0.1290   0.1040   91.841  audio_features
# 7          0.009560    0.0952   0.1820   71.989  audio_features
# 8          0.000000    0.1070   0.7470   82.695  audio_features
#
#                        id                                   uri  \
# 0  2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 1  5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 2  1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 3  1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# 4  20UK2eUwlRzNuW60gzITuj  spotify:track:20UK2eUwlRzNuW60gzITuj
# 5  4mn2kNTqiGLwaUR8JdhJ1l  spotify:track:4mn2kNTqiGLwaUR8JdhJ1l
# 6  6b2oQwSGFkzsMtQruIWm2p  spotify:track:6b2oQwSGFkzsMtQruIWm2p
# 7  2yoxjQT7P2D1dhvxJGWWi8  spotify:track:2yoxjQT7P2D1dhvxJGWWi8
# 8  3QGsuHI8jO1Rx4JWLUh9jd  spotify:track:3QGsuHI8jO1Rx4JWLUh9jd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 1  https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 2  https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 3  https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# 4  https://api.spotify.com/v1/tracks/20UK2eUwlRzN...
# 5  https://api.spotify.com/v1/tracks/4mn2kNTqiGLw...
# 6  https://api.spotify.com/v1/tracks/6b2oQwSGFkzs...
# 7  https://api.spotify.com/v1/tracks/2yoxjQT7P2D1...
# 8  https://api.spotify.com/v1/tracks/3QGsuHI8jO1R...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 1  https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 2  https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 3  https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# 4  https://api.spotify.com/v1/audio-analysis/20UK...       161022
# 5  https://api.spotify.com/v1/audio-analysis/4mn2...       269907
# 6  https://api.spotify.com/v1/audio-analysis/6b2o...       238640
# 7  https://api.spotify.com/v1/audio-analysis/2yox...       227013
# 8  https://api.spotify.com/v1/audio-analysis/3QGs...       187973
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4
# 5               3
# 6               4
# 7               4
# 8               4

# %%
liked_target = []

for i in range(disliked_df.shape[0]):
    liked_target.append(1)

# %%
disliked_df['target'] = liked_target
disliked_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.177   0.215    3    -9.886     1       0.0335      0.807000
# 1         0.530   0.497    0   -11.348     1       0.0322      0.498000
# 2         0.617   0.567    0    -4.188     1       0.0828      0.058400
# 3         0.214   0.367    6   -10.858     0       0.0321      0.844000
# 4         0.236   0.156    1   -16.973     0       0.0389      0.731000
# 5         0.316   0.484    9    -9.110     0       0.0308      0.000334
# 6         0.515   0.430    7    -9.935     1       0.0369      0.010200
# 7         0.443   0.461    0    -6.224     0       0.0257      0.143000
# 8         0.444   0.819   10    -4.078     0       0.3410      0.106000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000125    0.0921   0.0415   75.862  audio_features
# 1          0.000384    0.0665   0.1000  141.977  audio_features
# 2          0.000000    0.0933   0.5050   90.246  audio_features
# 3          0.018100    0.1880   0.1750   79.854  audio_features
# 4          0.000000    0.1270   0.0919   85.780  audio_features
# 5          0.004450    0.0912   0.2990  117.363  audio_features
# 6          0.000141    0.1290   0.1040   91.841  audio_features
# 7          0.009560    0.0952   0.1820   71.989  audio_features
# 8          0.000000    0.1070   0.7470   82.695  audio_features
#
#                        id                                   uri  \
# 0  2MfwT3SKUyF0na2LCa2fCp  spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 1  5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 2  1CnPYaKxTVb4LWOtiGOm0m  spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 3  1M8OAc4NnD5GFMUiqjebaS  spotify:track:1M8OAc4NnD5GFMUiqjebaS
# 4  20UK2eUwlRzNuW60gzITuj  spotify:track:20UK2eUwlRzNuW60gzITuj
# 5  4mn2kNTqiGLwaUR8JdhJ1l  spotify:track:4mn2kNTqiGLwaUR8JdhJ1l
# 6  6b2oQwSGFkzsMtQruIWm2p  spotify:track:6b2oQwSGFkzsMtQruIWm2p
# 7  2yoxjQT7P2D1dhvxJGWWi8  spotify:track:2yoxjQT7P2D1dhvxJGWWi8
# 8  3QGsuHI8jO1Rx4JWLUh9jd  spotify:track:3QGsuHI8jO1Rx4JWLUh9jd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 1  https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 2  https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 3  https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# 4  https://api.spotify.com/v1/tracks/20UK2eUwlRzN...
# 5  https://api.spotify.com/v1/tracks/4mn2kNTqiGLw...
# 6  https://api.spotify.com/v1/tracks/6b2oQwSGFkzs...
# 7  https://api.spotify.com/v1/tracks/2yoxjQT7P2D1...
# 8  https://api.spotify.com/v1/tracks/3QGsuHI8jO1R...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 1  https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 2  https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 3  https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# 4  https://api.spotify.com/v1/audio-analysis/20UK...       161022
# 5  https://api.spotify.com/v1/audio-analysis/4mn2...       269907
# 6  https://api.spotify.com/v1/audio-analysis/6b2o...       238640
# 7  https://api.spotify.com/v1/audio-analysis/2yox...       227013
# 8  https://api.spotify.com/v1/audio-analysis/3QGs...       187973
#
#    time_signature  target
# 0               3       1
# 1               4       1
# 2               4       1
# 3               4       1
# 4               4       1
# 5               3       1
# 6               4       1
# 7               4       1
# 8               4       1

# %%
#combining

frames = [liked_df, disliked_df]
  
result = pd.concat(frames).reset_index()
result
# Out:
#      index  danceability  energy  key  loudness  mode  speechiness  \
# 0        0         0.271   0.165    5   -20.652     1       0.0351
# 1        1         0.177   0.215    3    -9.886     1       0.0335
# 2        2         0.530   0.497    0   -11.348     1       0.0322
# 3        3         0.617   0.567    0    -4.188     1       0.0828
# 4        4         0.214   0.367    6   -10.858     0       0.0321
# ..     ...           ...     ...  ...       ...   ...          ...
# 104      4         0.236   0.156    1   -16.973     0       0.0389
# 105      5         0.316   0.484    9    -9.110     0       0.0308
# 106      6         0.515   0.430    7    -9.935     1       0.0369
# 107      7         0.443   0.461    0    -6.224     0       0.0257
# 108      8         0.444   0.819   10    -4.078     0       0.3410
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.729000          0.000002    0.1180   0.2030   77.082
# 1        0.807000          0.000125    0.0921   0.0415   75.862
# 2        0.498000          0.000384    0.0665   0.1000  141.977
# 3        0.058400          0.000000    0.0933   0.5050   90.246
# 4        0.844000          0.018100    0.1880   0.1750   79.854
# ..            ...               ...       ...      ...      ...
# 104      0.731000          0.000000    0.1270   0.0919   85.780
# 105      0.000334          0.004450    0.0912   0.2990  117.363
# 106      0.010200          0.000141    0.1290   0.1040   91.841
# 107      0.143000          0.009560    0.0952   0.1820   71.989
# 108      0.106000          0.000000    0.1070   0.7470   82.695
#
#                type                      id  \
# 0    audio_features  29U7stRjqHU6rMiS8BfaI9
# 1    audio_features  2MfwT3SKUyF0na2LCa2fCp
# 2    audio_features  5b7wNSn8yuj5ZZ3JAlzoBt
# 3    audio_features  1CnPYaKxTVb4LWOtiGOm0m
# 4    audio_features  1M8OAc4NnD5GFMUiqjebaS
# ..              ...                     ...
# 104  audio_features  20UK2eUwlRzNuW60gzITuj
# 105  audio_features  4mn2kNTqiGLwaUR8JdhJ1l
# 106  audio_features  6b2oQwSGFkzsMtQruIWm2p
# 107  audio_features  2yoxjQT7P2D1dhvxJGWWi8
# 108  audio_features  3QGsuHI8jO1Rx4JWLUh9jd
#
#                                       uri  \
# 0    spotify:track:29U7stRjqHU6rMiS8BfaI9
# 1    spotify:track:2MfwT3SKUyF0na2LCa2fCp
# 2    spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 3    spotify:track:1CnPYaKxTVb4LWOtiGOm0m
# 4    spotify:track:1M8OAc4NnD5GFMUiqjebaS
# ..                                    ...
# 104  spotify:track:20UK2eUwlRzNuW60gzITuj
# 105  spotify:track:4mn2kNTqiGLwaUR8JdhJ1l
# 106  spotify:track:6b2oQwSGFkzsMtQruIWm2p
# 107  spotify:track:2yoxjQT7P2D1dhvxJGWWi8
# 108  spotify:track:3QGsuHI8jO1Rx4JWLUh9jd
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/29U7stRjqHU6...
# 1    https://api.spotify.com/v1/tracks/2MfwT3SKUyF0...
# 2    https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 3    https://api.spotify.com/v1/tracks/1CnPYaKxTVb4...
# 4    https://api.spotify.com/v1/tracks/1M8OAc4NnD5G...
# ..                                                 ...
# 104  https://api.spotify.com/v1/tracks/20UK2eUwlRzN...
# 105  https://api.spotify.com/v1/tracks/4mn2kNTqiGLw...
# 106  https://api.spotify.com/v1/tracks/6b2oQwSGFkzs...
# 107  https://api.spotify.com/v1/tracks/2yoxjQT7P2D1...
# 108  https://api.spotify.com/v1/tracks/3QGsuHI8jO1R...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/29U7...       139227
# 1    https://api.spotify.com/v1/audio-analysis/2Mfw...       188864
# 2    https://api.spotify.com/v1/audio-analysis/5b7w...       345933
# 3    https://api.spotify.com/v1/audio-analysis/1CnP...       217603
# 4    https://api.spotify.com/v1/audio-analysis/1M8O...       281844
# ..                                                 ...          ...
# 104  https://api.spotify.com/v1/audio-analysis/20UK...       161022
# 105  https://api.spotify.com/v1/audio-analysis/4mn2...       269907
# 106  https://api.spotify.com/v1/audio-analysis/6b2o...       238640
# 107  https://api.spotify.com/v1/audio-analysis/2yox...       227013
# 108  https://api.spotify.com/v1/audio-analysis/3QGs...       187973
#
#      time_signature  target
# 0                 4       1
# 1                 3       1
# 2                 4       1
# 3                 4       1
# 4                 4       1
# ..              ...     ...
# 104               4       1
# 105               3       1
# 106               4       1
# 107               4       1
# 108               4       1
#
# [109 rows x 20 columns]

# %%
#shuffle
result = result.sample(frac = 1).reset_index()
result
# Out:
#      level_0  index  danceability  energy  key  loudness  mode  speechiness  \
# 0         80     80         0.492   0.590    4    -4.032     0       0.0313
# 1         64     64         0.417   0.329    6   -14.817     0       0.0330
# 2         65     65         0.386   0.445   11   -11.713     0       0.0377
# 3        101      1         0.530   0.497    0   -11.348     1       0.0322
# 4         40     40         0.532   0.495   10    -6.662     1       0.0343
# ..       ...    ...           ...     ...  ...       ...   ...          ...
# 104       14     14         0.510   0.574    7   -11.302     1       0.0337
# 105        6      6         0.316   0.484    9    -9.110     0       0.0308
# 106       58     58         0.602   0.371    9   -11.575     0       0.0322
# 107       92     92         0.679   0.283    0    -9.159     1       0.0328
# 108        8      8         0.443   0.461    0    -6.224     0       0.0257
#
#      acousticness  instrumentalness  ...  valence    tempo            type  \
# 0        0.001090          0.002300  ...   0.1790  117.637  audio_features
# 1        0.702000          0.910000  ...   0.0396  141.992  audio_features
# 2        0.606000          0.000243  ...   0.1880   77.881  audio_features
# 3        0.498000          0.000384  ...   0.1000  141.977  audio_features
# 4        0.659000          0.000000  ...   0.3080  124.936  audio_features
# ..            ...               ...  ...      ...      ...             ...
# 104      0.040100          0.000003  ...   0.2340  125.407  audio_features
# 105      0.000334          0.004450  ...   0.2990  117.363  audio_features
# 106      0.230000          0.000000  ...   0.2110  120.010  audio_features
# 107      0.069500          0.103000  ...   0.2750   77.036  audio_features
# 108      0.143000          0.009560  ...   0.1820   71.989  audio_features
#
#                          id                                   uri  \
# 0    2lCyQnftM6ptqC3vk7qeao  spotify:track:2lCyQnftM6ptqC3vk7qeao
# 1    1jYhmB4lXOdsOeD3p0CAoD  spotify:track:1jYhmB4lXOdsOeD3p0CAoD
# 2    5YwVDOWMKH7T0KtvpPSESQ  spotify:track:5YwVDOWMKH7T0KtvpPSESQ
# 3    5b7wNSn8yuj5ZZ3JAlzoBt  spotify:track:5b7wNSn8yuj5ZZ3JAlzoBt
# 4    4U45aEWtQhrm8A5mxPaFZ7  spotify:track:4U45aEWtQhrm8A5mxPaFZ7
# ..                      ...                                   ...
# 104  4Yv6i6vsR5RoSsuTX8Anr3  spotify:track:4Yv6i6vsR5RoSsuTX8Anr3
# 105  4mn2kNTqiGLwaUR8JdhJ1l  spotify:track:4mn2kNTqiGLwaUR8JdhJ1l
# 106  1RgiH5ucgoEWDKmGyA5drQ  spotify:track:1RgiH5ucgoEWDKmGyA5drQ
# 107  1CaE0HSFy3ACitYvvGsh3h  spotify:track:1CaE0HSFy3ACitYvvGsh3h
# 108  2yoxjQT7P2D1dhvxJGWWi8  spotify:track:2yoxjQT7P2D1dhvxJGWWi8
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2lCyQnftM6pt...
# 1    https://api.spotify.com/v1/tracks/1jYhmB4lXOds...
# 2    https://api.spotify.com/v1/tracks/5YwVDOWMKH7T...
# 3    https://api.spotify.com/v1/tracks/5b7wNSn8yuj5...
# 4    https://api.spotify.com/v1/tracks/4U45aEWtQhrm...
# ..                                                 ...
# 104  https://api.spotify.com/v1/tracks/4Yv6i6vsR5Ro...
# 105  https://api.spotify.com/v1/tracks/4mn2kNTqiGLw...
# 106  https://api.spotify.com/v1/tracks/1RgiH5ucgoEW...
# 107  https://api.spotify.com/v1/tracks/1CaE0HSFy3AC...
# 108  https://api.spotify.com/v1/tracks/2yoxjQT7P2D1...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2lCy...      229517
# 1    https://api.spotify.com/v1/audio-analysis/1jYh...      350333
# 2    https://api.spotify.com/v1/audio-analysis/5YwV...      239267
# 3    https://api.spotify.com/v1/audio-analysis/5b7w...      345933
# 4    https://api.spotify.com/v1/audio-analysis/4U45...      214240
# ..                                                 ...         ...
# 104  https://api.spotify.com/v1/audio-analysis/4Yv6...      250794
# 105  https://api.spotify.com/v1/audio-analysis/4mn2...      269907
# 106  https://api.spotify.com/v1/audio-analysis/1Rgi...      280371
# 107  https://api.spotify.com/v1/audio-analysis/1CaE...      243973
# 108  https://api.spotify.com/v1/audio-analysis/2yox...      227013
#
#      time_signature  target
# 0                 4       1
# 1                 4       1
# 2                 4       1
# 3                 4       1
# 4                 4       1
# ..              ...     ...
# 104               4       1
# 105               3       1
# 106               4       1
# 107               4       1
# 108               4       1
#
# [109 rows x 21 columns]

# %%
# Out:
# Counter({0: 11})
